# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

import torch.nn 

from torch.func import (vmap, jacrev)
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
def kin_unicycle(t, x, control_input):
    v, w = control_input  
    dx = np.zeros(3)
    dx[0] = np.cos(x[2]) * v
    dx[1] = np.sin(x[2]) * v
    dx[2] = w
    return dx

# %%
N_sample = 50 # number of trajectory for type
# ps: full dataset will be [n_sample * 8, 100, 2]

len_traj = 800 # number of step for traj

# define range of controls:  +-1 m/s for v and +-1 rad/s for w
input_range_pos = np.array([-0.25, +1])
input_range_neg = np.array([-1, 0.25])

# define 8 "type" of trajectory:
trajectory_input = []

# 1 straight line forward -> [v > 0, w = 0]
v = np.random.uniform(*input_range_pos, (N_sample, len_traj, 1))
w = np.zeros((N_sample, len_traj, 1))
trajectory_input.append(np.concatenate([v, w], axis=-1))

# 2 straight line backward -> [v < 0, w = 0]
v = np.random.uniform(*input_range_neg, (N_sample, len_traj, 1))
w = np.zeros((N_sample, len_traj, 1))
trajectory_input.append(np.concatenate([v, w], axis=-1))

# 3 arc of circle (left) forward ->  [v > 0, w > 0]
v = np.random.uniform(*input_range_pos, (N_sample, len_traj, 1))
w = np.random.uniform(*input_range_pos, (N_sample, len_traj, 1))
trajectory_input.append(np.concatenate([v, w], axis=-1))

# 4 arc of circle (left) backward -> [v < 0, w > 0]
v = np.random.uniform(*input_range_neg, (N_sample, len_traj, 1))
w = np.random.uniform(*input_range_pos, (N_sample, len_traj, 1))
trajectory_input.append(np.concatenate([v, w], axis=-1))

# 5 arc of circle (right) forward -> [v > 0, w < 0]
v = np.random.uniform(*input_range_pos, (N_sample, len_traj, 1))
w = np.random.uniform(*input_range_neg, (N_sample, len_traj, 1))
trajectory_input.append(np.concatenate([v, w], axis=-1))

# 6 arc of circle (right) backward ->  [v < 0, w < 0]
v = np.random.uniform(*input_range_neg, (N_sample, len_traj, 1))
w = np.random.uniform(*input_range_neg, (N_sample, len_traj, 1))
trajectory_input.append(np.concatenate([v, w], axis=-1))

# 7 pure rotation (right) -> [v = 0, w > 0]
v = np.zeros((N_sample, len_traj, 1))
w = np.random.uniform(*input_range_pos,  (N_sample, len_traj, 1))
trajectory_input.append(np.concatenate([v, w], axis=-1))

# 8 pure rotation (left) -> [v = 0, w < 0]
v = np.zeros((N_sample, len_traj, 1))
w = np.random.uniform(*input_range_neg, (N_sample, len_traj, 1))
trajectory_input.append(np.concatenate([v, w], axis=-1))


# 9 zero input + super small noise (+-0,05)
v = np.zeros((N_sample, len_traj, 1)) + np.random.uniform(-0.09, 0.09, (N_sample, len_traj, 1))
w = np.zeros((N_sample, len_traj, 1)) + np.random.uniform(-0.09, 0.09, (N_sample, len_traj, 1))
trajectory_input.append(np.concatenate([v, w], axis=-1))

input_dataset = np.concatenate(trajectory_input, axis=0)

# %%
n_step_constant_input = 10
delta_t_for_step = 0.01

print('MAX_RANGE FOR SINGLE TRANSITION:')
n_step_constant_input * delta_t_for_step
# Out:
# MAX_RANGE FOR SINGLE TRANSITION:
# 0.1

# %%
# discretize the input:

for i in range(0, input_dataset.shape[1], n_step_constant_input):
    input_dataset[:, i:i+n_step_constant_input, :] = input_dataset[:, i, :][:, np.newaxis, :]

# %%
input_dataset.reshape(-1, N_sample, len_traj, 2).shape
# Out:
# (9, 50, 800, 2)

# %%
# plot the discretize input
import matplotlib.pyplot as plt
import numpy as np

# Assuming `input_dataset` is your tensor with shape (N*8, 100, 2)


# Create the subplot grid
fig, axes = plt.subplots(9, 2, figsize=(10, 20))  # 9 rows, 2 columns

# Loop over the 8 options (reshape input for clarity)
reshaped_dataset = input_dataset.reshape(-1, N_sample, len_traj, 2)

for i in range(9):  # Loop over the 8 options
    # Plot the 0th dimension in the left column (axes[i, 0])
    for j in range(N_sample):
        axes[i, 0].plot(reshaped_dataset[i, j, :, 0], label=f'Sample {j+1}')
    axes[i, 0].set_title(f'Option {i+1} - Dim 0')
    axes[i, 0].set_ylim(-1, 1)

    # Plot the 1st dimension in the right column (axes[i, 1])
    for j in range(N_sample):
        axes[i, 1].plot(reshaped_dataset[i, j, :, 1], label=f'Sample {j+1}')
    axes[i, 1].set_title(f'Option {i+1} - Dim 1')
    axes[i, 1].set_ylim(-1, 1)


# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %%
delta_t_for_step, n_step_constant_input, "transtition time", delta_t_for_step * n_step_constant_input
# Out:
# (0.01, 10, 'transtition time', 0.1)

# %%
time_range = [0.0, len_traj*delta_t_for_step]
time_points = np.arange(time_range[0], time_range[1]+delta_t_for_step, delta_t_for_step)

# %%
#@ generate the trajectory

k = n_step_constant_input
X, Y = [], []
for traj in range(len(input_dataset)):
    traj_input = input_dataset[traj, :, :]

    # integrate the trajectory 
    initial_state = np.random.randn(3)
    states = [initial_state]
    controls = []
    times = [np.array([0.0])]
    for i in range(0, len(time_points)-1):

        t_span = [time_points[i], time_points[i+1]]
        control = traj_input[i, :]
        sol = solve_ivp(
            kin_unicycle,
            t_span, 
            states[-1], # last state as initial state
            args=(control,),
            t_eval=[t_span[1]], 
            method='RK45'
            )
        
        states.append(sol.y.squeeze())
        times.append(sol.t)
        controls.append(control)
        
    s = np.stack(states)
    c = np.stack(controls)
    t = np.stack(times)
    
    # create sample for dataset
    X_traj_i, Y_traj_i = [], []
    for i in range(0, len(c), k):
        x0 = s[i][np.newaxis, :].repeat(k, axis=0)
        c_substep = c[i:i+k]
        t = np.arange(0, delta_t_for_step * k, delta_t_for_step)[:, np.newaxis]

        x = np.hstack([x0, c_substep, t])
        X_traj_i.append(x)

        y = s[i:i+k]
        Y_traj_i.append(y)

    X.append(np.concatenate(X_traj_i))
    Y.append(np.concatenate(Y_traj_i)) 

X = np.stack(X).reshape(-1, N_sample, 6)
Y = np.stack(Y).reshape(-1, N_sample, 3)

# %%
x_max, x_min = Y[:, 0].max(), Y[:, 0].min()
y_max, y_min = Y[:, 1].max(), Y[:, 1].min()
theta_max, theta_min = Y[:, 2].max(), Y[:, 2].min()

v_max, v_min = X[:, :, 3].max(), X[:, :, 3].min()
w_max, w_min = X[:, :, 4].max(), X[:, :, 4].min()
t_max, t_min = X[:, :, 5].max(), X[:, :, 5].min()

# %%
max_range = torch.tensor(
    [x_max, y_max, theta_max, v_max, w_max, t_max],
    dtype=torch.float32
)

min_range = torch.tensor(
    [x_min, y_min, theta_min, v_min, w_min, t_min],
    dtype=torch.float32
)

dataset_range = (max_range, min_range)

# %%
dataset_range
# X Y Theta, V, W, time
# Out:
# (tensor([5.6094, 5.6092, 5.6091, 0.9999, 1.0000, 0.0900]),
#  tensor([-5.1768, -5.1780, -5.1792, -0.9998, -1.0000,  0.0000]))

# %%
# shuffle the dataset and split into train and test
idx = np.random.randint(0, X.shape[0], X.shape[0])
X = X[idx]
Y = Y[idx]

split = int(0.8 * X.shape[0])
X_train, Y_train = X[:split], Y[:split]
X_test, Y_test = X[split:], Y[split:]

X_train = torch.tensor(X_train, dtype=torch.float32)
Y_train = torch.tensor(Y_train, dtype=torch.float32)

X_test = torch.tensor(X_test, dtype=torch.float32)
Y_test = torch.tensor(Y_test, dtype=torch.float32)

# %%
class dataset(torch.utils.data.Dataset):
    def __init__(self, X, Y, device='cuda'):
        self.X = X.to(device)
        self.Y = Y.to(device)

    def __len__(self):
        return self.X.shape[0]

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# %%
train_dataset = dataset(X_train, Y_train)   
test_dataset = dataset(X_test, Y_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)

# %%
class MLP(torch.nn.Module):

    def __init__(
        self,
        state_dim,
        input_dim,
        latent_dim,
        n_hidden_layer=2,
        time=False
    ):
        super(MLP, self).__init__()

        self.input_shape = state_dim + input_dim
        self.state_dim = state_dim

        if time:
            self.input_shape += 1

        self.fc = torch.nn.Sequential(
            torch.nn.Linear(self.input_shape, latent_dim),
            torch.nn.Tanh(),
            torch.nn.Linear(latent_dim, latent_dim),
            torch.nn.Tanh(),
            torch.nn.Linear(latent_dim, state_dim),
        )

    
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        x has dimension [batch_size, state_dim + action_dim + state_dim]
        """
        return self.fc(x)

# %%
def uniKinTorch(x, u):

    if x.ndim == 1:
        x = x.unsqueeze(0)
    if u.ndim == 1:
        u = u.unsqueeze(0)

    theta = x[:, 2]
    v = u[:, 0]
    w = u[:, 1]

    dx = torch.zeros_like(x)
    dx[:, 0] = torch.cos(theta) * v
    dx[:, 1] = torch.sin(theta) * v
    dx[:, 2] = w

    return dx

# %%
from dataclasses import dataclass

@dataclass
class PinnParams:

    state_dim = 3
    input_dim = 2

    batch_size = 1024
    particle_sample_for_grad = 1024
    particle_sample_for_zero_vel = 1024

    latent_dim = 124
    n_hidden_layer = 2
    model_path = None
    use_pretrain = None

    imit_loss_weight = 1.0
    boundary_loss_weight = 1.0
    physic_loss_weight = 1.0

    lr = 1e-5
    weight_decay = 1e-8

# %%
class Pinn_learner:


    def __init__(
        self,
        ode_fn,
        params,    
        input_range,
        dataset_train,
        dataset_test=None,
        use_pretrain=False, 
        device="cuda"):
        
        
        # robot model, dynamics
        self.state_dim = params.state_dim
        self.input_dim = params.input_dim
        self.ode_fn = ode_fn


        self.model_path = params.model_path
        self.device = device
        self.model = MLP(
            state_dim=params.state_dim,
            input_dim=params.input_dim,
            n_hidden_layer=params.n_hidden_layer,
            latent_dim=params.latent_dim,
            time=True
        ).to(self.device)

        if params.use_pretrain:
            self.model.load_state_dict(torch.load(self.model_path, weights_only=True))
        
        # dataset 
        self.dataset_train = dataset_train
        self.dataloader = torch.utils.data.DataLoader(
            self.dataset_train, 
            batch_size=params.batch_size, 
            shuffle=True
        )

        self.dataset_test = dataset_test
        self.dataloader_test = torch.utils.data.DataLoader(
            self.dataset_test,
            batch_size=len(self.dataset_test),
            shuffle=False
        )

        self.particle_batch_size_boundary = params.particle_sample_for_grad
        self.particle_batch_size_gradient = params.particle_sample_for_zero_vel

        self.max_range = input_range[0].to(self.device)
        self.min_range = input_range[1].to(self.device) 

        # training component 
        self.optimizer = torch.optim.Adam(
            self.model.parameters(),
            lr=params.lr,
            weight_decay=params.weight_decay
        )

        self.imit_loss_weight = params.imit_loss_weight
        self.boundary_loss_weight = params.boundary_loss_weight
        self.physic_loss_weight = params.physic_loss_weight

        self.mse = torch.nn.MSELoss()


    # config functions
    # -------------------
    def config_batch_size(
        self,
        batch_size,
        particle_batch_size_boundary,
        particle_batch_size_gradient):

        if batch_size == -1:
            self.batch_size = len(self.dataset)
        else:
            self.batch_size = batch_size
        
        if particle_batch_size_boundary == -1:
            self.particle_batch_size_boundary = len(self.dataset)//2
        else:
            self.particle_batch_size_boundary = particle_batch_size_boundary

        if particle_batch_size_gradient == -1:
            self.particle_batch_size_gradient = len(self.dataset)//2
        else:
            self.particle_batch_size_gradient = particle_batch_size_gradient


    # training functions
    # -------------------
    def calc_loss(self, batch):
        
        statistics = {}
        loss = 0

        if self.imit_loss_weight > 0:
            imit_loss = self.calc_mse_loss(batch)
            statistics['imit_loss'] = imit_loss.item()
            loss += imit_loss
        
        if self.boundary_loss_weight > 0:
            boundary_loss = self.calc_boundary_loss()
            statistics['boundary_loss'] = boundary_loss.item()
            loss += boundary_loss

        if self.physic_loss_weight > 0:
            physic_loss = self.calc_physic_loss()
            statistics['physic_loss'] = physic_loss.item()
            loss += physic_loss

        statistics['total_loss'] = loss.item()

        return loss, statistics

    def train_step(self):
        for i, batch in enumerate(self.dataloader):
            self.optimizer.zero_grad()
            loss, stat = self.calc_loss(batch)
            loss.backward()
            self.optimizer.step()
        return stat


    # loss definition
    # -------------------
    def calc_physic_loss(self):

        N_particle = self.particle_batch_size_gradient

        # sample the particle        
        sampled_input = torch.rand(N_particle, self.state_dim + self.input_dim + 1).to(self.device)
        # normalize the particle in the respective range

        sampled_input = sampled_input * (self.max_range - self.min_range) + self.min_range
        sampled_input.requires_grad = True

        # jacobian --> [batch, state_dim, (state_dim + input_dim + 1(time))]
        jac = vmap(jacrev(self.model))(sampled_input).squeeze()
        state_derivative_numeric = jac[:, :, -1]        

        # ode prediction
        state_derivative_analytic = self.ode_fn(
            sampled_input[:, :self.state_dim],
            sampled_input[:, self.state_dim:-1]
        )

        # error:  
        error = state_derivative_numeric - state_derivative_analytic

        # physics cost:
        physic_loss = torch.mean(error**2)

        return self.physic_loss_weight * physic_loss

    def calc_mse_loss(self, batch):
        X, Y = batch
        pred_y = self.model(X)
        return self.imit_loss_weight * self.mse(pred_y, Y)

    def calc_boundary_loss(self):
        N_particle = self.particle_batch_size_boundary

        # sample the particle
        sampled_input = torch.rand(N_particle, self.state_dim + self.input_dim + 1).to(self.device)
        
        # normalize in the respective range 
        sampled_input = sampled_input * (self.max_range - self.min_range) + self.min_range
        
        # zeros the velocity
        sampled_input[:, self.state_dim : self.state_dim+self.input_dim] = 0.0
        

        # 0 velocity means that we want to predict the initial state 
        # the models must be a kind of identity function 
        target_prediction = sampled_input[:, :self.state_dim].clone()

        sampled_input.requires_grad = True

        pred_output = self.model(sampled_input)
        boundary_loss = self.mse(pred_output, target_prediction)

        return self.boundary_loss_weight * boundary_loss


    def eval(self):
        with torch.no_grad():
            batch = next(iter(self.dataloader_test))
            loss = self.calc_mse_loss(batch)
            return loss.item()

# %%
learner = Pinn_learner(
    uniKinTorch,
    PinnParams, 
    dataset_train=train_dataset, 
    dataset_test=test_dataset,
    input_range=dataset_range
    )

log_loss_train = []
log_loss_test = []

# %%
for epoch in range(20_000):

    statistics = learner.train_step()
    log_loss_train.append(statistics)
    if epoch % 10 == 0:
        log_loss_test.append(learner.eval())
        print(f"Epoch {epoch} : trained for: {len(log_loss_train)} - \n",
              f"TOT Loss: {statistics['total_loss']} ",
              f"Imitation Loss: {statistics['imit_loss']} ",
              f"Boundary Loss: {statistics['boundary_loss']} ", 
              f"Physic Loss: {statistics['physic_loss']} ",
              f"test imit loss: {log_loss_test[-1]}"
              )
        print()
# Out:
# Epoch 0 : trained for: 60285 -
#  TOT Loss: 1.11888275569072e-05  Imitation Loss: 1.0160637202716316e-06  Boundary Loss: 8.858934847921773e-07  Physic Loss: 9.28687040868681e-06  test imit loss: 9.569697567712865e-07
#
# Epoch 10 : trained for: 60295 -
#  TOT Loss: 1.0355823178542778e-05  Imitation Loss: 8.16891031263367e-07  Boundary Loss: 7.785982916175271e-07  Physic Loss: 8.760333912505303e-06  test imit loss: 9.65547201303707e-07
#
# Epoch 20 : trained for: 60305 -
#  TOT Loss: 1.0948202543659136e-05  Imitation Loss: 1.1886634183611022e-06  Boundary Loss: 8.001128435353166e-07  Physic Loss: 8.959426850196905e-06  test imit loss: 9.640215239414829e-07
#
# Epoch 30 : trained for: 60315 -
#  TOT Loss: 1.0845041288121138e-05  Imitation Loss: 8.8239499973497e-07  Boundary Loss: 6.962395673326682e-07  Physic Loss: 9.266406777896918e-06  test imit loss: 9.732342505230918e-07
#
# Epoch 40 : trained for: 60325 -
#  TOT Loss: 1.0852663763216697e-05  Imitation Loss: 8.820268817544274e-07  Boundary Loss: 6.765309876755055e-07  Physic Loss: 9.294106348534115e-06  test imit loss: 9.531124760542298e-07
#
# Epoch 50 : trained for: 60335 -
#  TOT Loss: 1.0198598829447292e-05  Imitation Loss: 9.939009260051535e-07  Boundary Loss: 6.034024409018457e-07  Physic Loss: 8.60129512147978e-06  test imit loss: 9.628349744161824e-07
#
# Epoch 60 : trained for: 60345 -
#  TOT Loss: 1.0253782420477364e-05  Imitation Loss: 1.2771478168360773e-06  Boundary Loss: 8.813094041215663e-07  Physic Loss: 8.095325028989464e-06  test imit loss: 9.716403610582347e-07
#
# Epoch 70 : trained for: 60355 -
#  TOT Loss: 1.0184374332311563e-05  Imitation Loss: 8.947189371610875e-07  Boundary Loss: 6.189789019117597e-07  Physic Loss: 8.670676834299229e-06  test imit loss: 9.543774694975582e-07
#
# Epoch 80 : trained for: 60365 -
#  TOT Loss: 1.0199917596764863e-05  Imitation Loss: 9.315108400187455e-07  Boundary Loss: 5.894303853892779e-07  Physic Loss: 8.678976882947609e-06  test imit loss: 9.705610182209057e-07
#
# Epoch 90 : trained for: 60375 -
#  TOT Loss: 1.0491672583157197e-05  Imitation Loss: 9.382496841681132e-07  Boundary Loss: 5.748970011154597e-07  Physic Loss: 8.978526238934137e-06  test imit loss: 9.63789943853044e-07
#
# Epoch 100 : trained for: 60385 -
#  TOT Loss: 9.816017154662404e-06  Imitation Loss: 7.92765490587044e-07  Boundary Loss: 7.644456445632386e-07  Physic Loss: 8.258805792138446e-06  test imit loss: 9.6335952548543e-07
#
# Epoch 110 : trained for: 60395 -
#  TOT Loss: 1.1488002201076597e-05  Imitation Loss: 1.2310021020311979e-06  Boundary Loss: 6.818461315560853e-07  Physic Loss: 9.575153853802476e-06  test imit loss: 9.576573347658268e-07
#
# Epoch 120 : trained for: 60405 -
#  TOT Loss: 1.1061852092097979e-05  Imitation Loss: 1.179331206913048e-06  Boundary Loss: 7.778111239531427e-07  Physic Loss: 9.104709533858113e-06  test imit loss: 9.569832855049754e-07
#
# Epoch 130 : trained for: 60415 -
#  TOT Loss: 1.0173289410886355e-05  Imitation Loss: 9.050335165738943e-07  Boundary Loss: 6.068513584978064e-07  Physic Loss: 8.661404535814654e-06  test imit loss: 9.542033012621687e-07
#
# Epoch 140 : trained for: 60425 -
#  TOT Loss: 1.0508862942515407e-05  Imitation Loss: 8.310871066896652e-07  Boundary Loss: 7.78424805503164e-07  Physic Loss: 8.899351087165996e-06  test imit loss: 9.652377457314287e-07
#
# Epoch 150 : trained for: 60435 -
#  TOT Loss: 1.0019875844591297e-05  Imitation Loss: 8.175724701686704e-07  Boundary Loss: 5.461358796310378e-07  Physic Loss: 8.656167665321846e-06  test imit loss: 9.699155043563223e-07
#
# Epoch 160 : trained for: 60445 -
#  TOT Loss: 1.0614266102493275e-05  Imitation Loss: 9.180951678899874e-07  Boundary Loss: 6.384257176250685e-07  Physic Loss: 9.057745046447963e-06  test imit loss: 9.630172144170501e-07
#
# Epoch 170 : trained for: 60455 -
#  TOT Loss: 1.0428077985125128e-05  Imitation Loss: 1.065570017999562e-06  Boundary Loss: 6.248079671422602e-07  Physic Loss: 8.737700227356981e-06  test imit loss: 9.60595571086742e-07
#
# Epoch 180 : trained for: 60465 -
#  TOT Loss: 9.720508387545124e-06  Imitation Loss: 8.908963877729548e-07  Boundary Loss: 6.812059609728749e-07  Physic Loss: 8.148405868269037e-06  test imit loss: 9.705662478154409e-07
#
# Epoch 190 : trained for: 60475 -
#  TOT Loss: 1.0652403034328017e-05  Imitation Loss: 1.1571927416298422e-06  Boundary Loss: 6.091756858950248e-07  Physic Loss: 8.886034265742637e-06  test imit loss: 9.509788583272893e-07
#
# Epoch 200 : trained for: 60485 -
#  TOT Loss: 1.0237265996693168e-05  Imitation Loss: 9.441304769097769e-07  Boundary Loss: 7.048550969557255e-07  Physic Loss: 8.588280252297409e-06  test imit loss: 9.628541874917573e-07
#
# Epoch 210 : trained for: 60495 -
#  TOT Loss: 1.0807560101966374e-05  Imitation Loss: 8.327202749569551e-07  Boundary Loss: 7.130624908313621e-07  Physic Loss: 9.261777449864894e-06  test imit loss: 9.483294434176059e-07
#
# Epoch 220 : trained for: 60505 -
#  TOT Loss: 1.0879346518777311e-05  Imitation Loss: 8.30358658276964e-07  Boundary Loss: 6.398653340511373e-07  Physic Loss: 9.409122867509723e-06  test imit loss: 9.528031341687893e-07
#
# Epoch 230 : trained for: 60515 -
#  TOT Loss: 1.046322904585395e-05  Imitation Loss: 9.281171173824987e-07  Boundary Loss: 6.019917009325582e-07  Physic Loss: 8.933120625442825e-06  test imit loss: 9.480581297793833e-07
#
# Epoch 240 : trained for: 60525 -
#  TOT Loss: 1.109549975808477e-05  Imitation Loss: 8.965815823103185e-07  Boundary Loss: 6.268722927416093e-07  Physic Loss: 9.572046110406518e-06  test imit loss: 9.564525953464909e-07
#
# Epoch 250 : trained for: 60535 -
#  TOT Loss: 1.0015073712565936e-05  Imitation Loss: 9.800004363569315e-07  Boundary Loss: 6.60020702980546e-07  Physic Loss: 8.375052857445553e-06  test imit loss: 9.671897487351089e-07
#
# Epoch 260 : trained for: 60545 -
#  TOT Loss: 1.0393759112048429e-05  Imitation Loss: 8.125416002258135e-07  Boundary Loss: 5.91599700783263e-07  Physic Loss: 8.989617526822258e-06  test imit loss: 9.707518984214403e-07
#
# Epoch 270 : trained for: 60555 -
#  TOT Loss: 9.669444807514083e-06  Imitation Loss: 9.497275073044875e-07  Boundary Loss: 6.646756673944765e-07  Physic Loss: 8.055041689658538e-06  test imit loss: 9.457435794502089e-07
#
# Epoch 280 : trained for: 60565 -
#  TOT Loss: 1.0008394383476116e-05  Imitation Loss: 7.861364110794966e-07  Boundary Loss: 7.582651733173407e-07  Physic Loss: 8.463992344331928e-06  test imit loss: 9.58938358053274e-07
#
# Epoch 290 : trained for: 60575 -
#  TOT Loss: 9.40239624469541e-06  Imitation Loss: 9.556166560287238e-07  Boundary Loss: 7.643774893040245e-07  Physic Loss: 7.682402610953432e-06  test imit loss: 9.63618390414922e-07
#
# Epoch 300 : trained for: 60585 -
#  TOT Loss: 1.0261698662361596e-05  Imitation Loss: 8.367102850570518e-07  Boundary Loss: 7.042726792860776e-07  Physic Loss: 8.720715413801372e-06  test imit loss: 9.587812428435427e-07
#
# Epoch 310 : trained for: 60595 -
#  TOT Loss: 9.217174010700546e-06  Imitation Loss: 8.615018600721669e-07  Boundary Loss: 7.348244253080338e-07  Physic Loss: 7.62084800953744e-06  test imit loss: 9.566814469508245e-07
#
# Epoch 320 : trained for: 60605 -
#  TOT Loss: 1.0316409316146746e-05  Imitation Loss: 9.528547479931149e-07  Boundary Loss: 6.388274300661578e-07  Physic Loss: 8.724727194930892e-06  test imit loss: 9.479325626671198e-07
#
# Epoch 330 : trained for: 60615 -
#  TOT Loss: 9.781195331015624e-06  Imitation Loss: 9.581932545188465e-07  Boundary Loss: 6.02093848556251e-07  Physic Loss: 8.22090805741027e-06  test imit loss: 9.485702889833192e-07
#
# Epoch 340 : trained for: 60625 -
#  TOT Loss: 1.0129936526936945e-05  Imitation Loss: 1.0085135500048636e-06  Boundary Loss: 5.828084113090881e-07  Physic Loss: 8.538614565622993e-06  test imit loss: 9.644926421970013e-07
#
# Epoch 350 : trained for: 60635 -
#  TOT Loss: 9.539670827507507e-06  Imitation Loss: 8.044777359828004e-07  Boundary Loss: 7.072565040289192e-07  Physic Loss: 8.0279369285563e-06  test imit loss: 9.513703389529837e-07
#
# Epoch 360 : trained for: 60645 -
#  TOT Loss: 1.0580191883491352e-05  Imitation Loss: 8.893101153262251e-07  Boundary Loss: 5.685051291948184e-07  Physic Loss: 9.122376468440052e-06  test imit loss: 9.453410712012555e-07
#
# Epoch 370 : trained for: 60655 -
#  TOT Loss: 9.877034244709648e-06  Imitation Loss: 7.759081199765205e-07  Boundary Loss: 6.492628017440438e-07  Physic Loss: 8.451863322989084e-06  test imit loss: 9.74783120000211e-07
#
# Epoch 380 : trained for: 60665 -
#  TOT Loss: 1.025494475470623e-05  Imitation Loss: 9.283924669034604e-07  Boundary Loss: 8.410066811848083e-07  Physic Loss: 8.485545549774542e-06  test imit loss: 9.474653666075028e-07
#
# Epoch 390 : trained for: 60675 -
#  TOT Loss: 1.0022051355917938e-05  Imitation Loss: 7.75593889557058e-07  Boundary Loss: 7.643797630407789e-07  Physic Loss: 8.482077646476682e-06  test imit loss: 9.467655104344885e-07
#
# Epoch 400 : trained for: 60685 -
#  TOT Loss: 1.0013292012445163e-05  Imitation Loss: 8.996793781079759e-07  Boundary Loss: 6.600666893064044e-07  Physic Loss: 8.453545888187364e-06  test imit loss: 9.499698307990911e-07
#
# Epoch 410 : trained for: 60695 -
#  TOT Loss: 1.0770740118459798e-05  Imitation Loss: 7.228417189253378e-07  Boundary Loss: 7.879003760535852e-07  Physic Loss: 9.259998478228226e-06  test imit loss: 9.598828683010652e-07
#
# Epoch 420 : trained for: 60705 -
#  TOT Loss: 1.0258054317091592e-05  Imitation Loss: 9.410915708940593e-07  Boundary Loss: 7.59185127208184e-07  Physic Loss: 8.557777618989348e-06  test imit loss: 9.54316305978864e-07
#
# Epoch 430 : trained for: 60715 -
#  TOT Loss: 9.66824336501304e-06  Imitation Loss: 9.237515428139886e-07  Boundary Loss: 6.704398174406379e-07  Physic Loss: 8.074051947914995e-06  test imit loss: 9.583305882188142e-07
#
# Epoch 440 : trained for: 60725 -
#  TOT Loss: 1.0638301318977028e-05  Imitation Loss: 9.54415895648708e-07  Boundary Loss: 7.295338946278207e-07  Physic Loss: 8.954351869761012e-06  test imit loss: 9.56453391154355e-07
#
# Epoch 450 : trained for: 60735 -
#  TOT Loss: 1.050570426741615e-05  Imitation Loss: 8.234608799284615e-07  Boundary Loss: 7.450573775713565e-07  Physic Loss: 8.93718606675975e-06  test imit loss: 9.610620281819138e-07
#
# Epoch 460 : trained for: 60745 -
#  TOT Loss: 1.1092348358943127e-05  Imitation Loss: 1.2020054782624356e-06  Boundary Loss: 7.020270231805625e-07  Physic Loss: 9.188315743813291e-06  test imit loss: 9.611193263481255e-07
#
# Epoch 470 : trained for: 60755 -
#  TOT Loss: 1.1400203220546246e-05  Imitation Loss: 1.2157360060882638e-06  Boundary Loss: 6.745181053702254e-07  Physic Loss: 9.50994945014827e-06  test imit loss: 9.46546833802131e-07
#
# Epoch 480 : trained for: 60765 -
#  TOT Loss: 9.141603186435532e-06  Imitation Loss: 8.357376941603434e-07  Boundary Loss: 6.673679990853998e-07  Physic Loss: 7.638497663720045e-06  test imit loss: 9.53888729782193e-07
#
# Epoch 490 : trained for: 60775 -
#  TOT Loss: 1.0537472007854376e-05  Imitation Loss: 8.722265079086355e-07  Boundary Loss: 6.069035407563206e-07  Physic Loss: 9.058341674972326e-06  test imit loss: 9.482147333983448e-07
#
# Epoch 500 : trained for: 60785 -
#  TOT Loss: 1.0632822522893548e-05  Imitation Loss: 9.216709599968453e-07  Boundary Loss: 5.974703185529506e-07  Physic Loss: 9.113680789596401e-06  test imit loss: 9.628007546780282e-07
#
# Epoch 510 : trained for: 60795 -
#  TOT Loss: 1.0492744877410587e-05  Imitation Loss: 1.1715385426214198e-06  Boundary Loss: 6.099432425799023e-07  Physic Loss: 8.711263035365846e-06  test imit loss: 1.021173261506192e-06
#
# Epoch 520 : trained for: 60805 -
#  TOT Loss: 1.0253589607600588e-05  Imitation Loss: 8.481651434522064e-07  Boundary Loss: 6.762351745237538e-07  Physic Loss: 8.72918917593779e-06  test imit loss: 9.57056954575819e-07
#
# Epoch 530 : trained for: 60815 -
#  TOT Loss: 1.1079871910624206e-05  Imitation Loss: 1.2005307326035108e-06  Boundary Loss: 6.925291700099478e-07  Physic Loss: 9.18681234907126e-06  test imit loss: 9.443123190067126e-07
#
# Epoch 540 : trained for: 60825 -
#  TOT Loss: 1.0909501725109294e-05  Imitation Loss: 8.442277703579748e-07  Boundary Loss: 7.841674687369959e-07  Physic Loss: 9.281106940761674e-06  test imit loss: 9.523026847091387e-07
#
# Epoch 550 : trained for: 60835 -
#  TOT Loss: 1.192884155898355e-05  Imitation Loss: 8.489641345477139e-07  Boundary Loss: 8.817569323582575e-07  Physic Loss: 1.019812043523416e-05  test imit loss: 9.482204745836498e-07
#
# Epoch 560 : trained for: 60845 -
#  TOT Loss: 1.0619114618748426e-05  Imitation Loss: 9.417160526936641e-07  Boundary Loss: 8.098886610241607e-07  Physic Loss: 8.867509677656926e-06  test imit loss: 9.498323265688668e-07
#
# Epoch 570 : trained for: 60855 -
#  TOT Loss: 9.482955647399649e-06  Imitation Loss: 9.00710915630043e-07  Boundary Loss: 6.805652787988947e-07  Physic Loss: 7.90167905506678e-06  test imit loss: 9.530318720862851e-07
#
# Epoch 580 : trained for: 60865 -
#  TOT Loss: 9.843284715316258e-06  Imitation Loss: 8.205634003388695e-07  Boundary Loss: 6.899067557242233e-07  Physic Loss: 8.332815014000516e-06  test imit loss: 9.524292181595229e-07
#
# Epoch 590 : trained for: 60875 -
#  TOT Loss: 1.0464448678249028e-05  Imitation Loss: 1.0154083156521665e-06  Boundary Loss: 6.557797860295977e-07  Physic Loss: 8.793260349193588e-06  test imit loss: 9.461186891712714e-07
#
# Epoch 600 : trained for: 60885 -
#  TOT Loss: 1.0605725037748925e-05  Imitation Loss: 1.2261344863873092e-06  Boundary Loss: 6.565345529452316e-07  Physic Loss: 8.723056453163736e-06  test imit loss: 9.55039922700962e-07
#
# Epoch 610 : trained for: 60895 -
#  TOT Loss: 9.73011447058525e-06  Imitation Loss: 9.419285333933658e-07  Boundary Loss: 5.740174628954264e-07  Physic Loss: 8.214168701670133e-06  test imit loss: 9.430209502170328e-07
#
# Epoch 620 : trained for: 60905 -
#  TOT Loss: 1.034549768519355e-05  Imitation Loss: 8.6962859313644e-07  Boundary Loss: 4.956887096341234e-07  Physic Loss: 8.980180609796662e-06  test imit loss: 9.428197813576844e-07
#
# Epoch 630 : trained for: 60915 -
#  TOT Loss: 9.72246652963804e-06  Imitation Loss: 1.1456476158855367e-06  Boundary Loss: 7.054635489112115e-07  Physic Loss: 7.871355592214968e-06  test imit loss: 9.366473818772647e-07
#
# Epoch 640 : trained for: 60925 -
#  TOT Loss: 9.510096788289957e-06  Imitation Loss: 8.233926109824097e-07  Boundary Loss: 5.54015514353523e-07  Physic Loss: 8.1326888903277e-06  test imit loss: 9.455220038034895e-07
#
# Epoch 650 : trained for: 60935 -
#  TOT Loss: 1.0486666724318638e-05  Imitation Loss: 9.250107382285933e-07  Boundary Loss: 6.825195555393293e-07  Physic Loss: 8.879136657924391e-06  test imit loss: 9.441276347388339e-07
#
# Epoch 660 : trained for: 60945 -
#  TOT Loss: 9.609906555851921e-06  Imitation Loss: 8.418072638960439e-07  Boundary Loss: 7.161449389059271e-07  Physic Loss: 8.051953955146018e-06  test imit loss: 9.381770951222279e-07
#
# Epoch 670 : trained for: 60955 -
#  TOT Loss: 1.050680202752119e-05  Imitation Loss: 8.947166065809142e-07  Boundary Loss: 5.633625050904811e-07  Physic Loss: 9.048722859006375e-06  test imit loss: 9.480485800850147e-07
#
# Epoch 680 : trained for: 60965 -
#  TOT Loss: 9.688308637123555e-06  Imitation Loss: 7.338197747230879e-07  Boundary Loss: 7.198561320365116e-07  Physic Loss: 8.234632332460023e-06  test imit loss: 9.473046134189644e-07
#
# Epoch 690 : trained for: 60975 -
#  TOT Loss: 1.0445755833643489e-05  Imitation Loss: 9.903405953082256e-07  Boundary Loss: 5.486808731802739e-07  Physic Loss: 8.906734365154989e-06  test imit loss: 9.453544294046878e-07
#
# Epoch 700 : trained for: 60985 -
#  TOT Loss: 1.0500022654014174e-05  Imitation Loss: 8.570491445425432e-07  Boundary Loss: 6.38941287434136e-07  Physic Loss: 9.004032108350657e-06  test imit loss: 9.384207260154653e-07
#
# Epoch 710 : trained for: 60995 -
#  TOT Loss: 9.898200005409308e-06  Imitation Loss: 8.26320160740579e-07  Boundary Loss: 5.478856337504112e-07  Physic Loss: 8.523994438291993e-06  test imit loss: 9.426899509890063e-07
#
# Epoch 720 : trained for: 61005 -
#  TOT Loss: 1.0569350706646219e-05  Imitation Loss: 8.518228469256428e-07  Boundary Loss: 7.465272346962593e-07  Physic Loss: 8.971001079771668e-06  test imit loss: 9.416373814019607e-07
#
# Epoch 730 : trained for: 61015 -
#  TOT Loss: 9.816410965868272e-06  Imitation Loss: 9.204591719935706e-07  Boundary Loss: 1.0084152108902344e-06  Physic Loss: 7.88753641245421e-06  test imit loss: 9.341844133814448e-07
#
# Epoch 740 : trained for: 61025 -
#  TOT Loss: 1.0618474334478378e-05  Imitation Loss: 1.1273689324298175e-06  Boundary Loss: 6.36310915069771e-07  Physic Loss: 8.854794032231439e-06  test imit loss: 9.522581194687518e-07
#
# Epoch 750 : trained for: 61035 -
#  TOT Loss: 1.0155379641219042e-05  Imitation Loss: 9.141177770288778e-07  Boundary Loss: 5.911576863582013e-07  Physic Loss: 8.650104064145125e-06  test imit loss: 9.460451337872655e-07
#
# Epoch 760 : trained for: 61045 -
#  TOT Loss: 1.0016739906859584e-05  Imitation Loss: 9.230435580320773e-07  Boundary Loss: 7.113467290764675e-07  Physic Loss: 8.382349733437877e-06  test imit loss: 9.357988233205106e-07
#
# Epoch 770 : trained for: 61055 -
#  TOT Loss: 9.360816875414457e-06  Imitation Loss: 9.247924595001678e-07  Boundary Loss: 6.031187353983114e-07  Physic Loss: 7.832905794202816e-06  test imit loss: 9.352156098429987e-07
#
# Epoch 780 : trained for: 61065 -
#  TOT Loss: 9.925079211825505e-06  Imitation Loss: 8.181937118934002e-07  Boundary Loss: 5.487754606292583e-07  Physic Loss: 8.558110494050197e-06  test imit loss: 9.648840659792768e-07
#
# Epoch 790 : trained for: 61075 -
#  TOT Loss: 1.1201530469406862e-05  Imitation Loss: 7.484021011805453e-07  Boundary Loss: 7.977926088642562e-07  Physic Loss: 9.65533581620548e-06  test imit loss: 9.487926604379027e-07
#
# Epoch 800 : trained for: 61085 -
#  TOT Loss: 1.043111569742905e-05  Imitation Loss: 8.354717806469125e-07  Boundary Loss: 6.117472821642878e-07  Physic Loss: 8.983896805148106e-06  test imit loss: 9.357423778055818e-07
#
# Epoch 810 : trained for: 61095 -
#  TOT Loss: 1.0529827704885975e-05  Imitation Loss: 7.54754978515848e-07  Boundary Loss: 7.556814125564415e-07  Physic Loss: 9.019391654874198e-06  test imit loss: 9.65825734056125e-07
#
# Epoch 820 : trained for: 61105 -
#  TOT Loss: 1.0201712939306162e-05  Imitation Loss: 9.572094086252037e-07  Boundary Loss: 6.648368753303657e-07  Physic Loss: 8.579666427976917e-06  test imit loss: 9.487919783168763e-07
#
# Epoch 830 : trained for: 61115 -
#  TOT Loss: 9.676492481958121e-06  Imitation Loss: 9.472385613662482e-07  Boundary Loss: 6.458975576606463e-07  Physic Loss: 8.083356078714132e-06  test imit loss: 9.457677379032248e-07
#
# Epoch 840 : trained for: 61125 -
#  TOT Loss: 1.054913445841521e-05  Imitation Loss: 9.521858714833797e-07  Boundary Loss: 6.90530100655451e-07  Physic Loss: 8.906418770493474e-06  test imit loss: 9.432844763068715e-07
#
# Epoch 850 : trained for: 61135 -
#  TOT Loss: 1.0468906111782417e-05  Imitation Loss: 7.87367127941252e-07  Boundary Loss: 6.017547207193275e-07  Physic Loss: 9.079783922061324e-06  test imit loss: 9.406345498064184e-07
#
# Epoch 860 : trained for: 61145 -
#  TOT Loss: 9.873150702333078e-06  Imitation Loss: 8.32740340683813e-07  Boundary Loss: 6.00861767452443e-07  Physic Loss: 8.439548764727078e-06  test imit loss: 9.510363838671765e-07
#
# Epoch 870 : trained for: 61155 -
#  TOT Loss: 9.593866707291454e-06  Imitation Loss: 8.034213010432723e-07  Boundary Loss: 6.716876441714703e-07  Physic Loss: 8.118757250485942e-06  test imit loss: 9.476095215177338e-07
#
# Epoch 880 : trained for: 61165 -
#  TOT Loss: 1.048907870426774e-05  Imitation Loss: 9.529781550554617e-07  Boundary Loss: 7.077014743117616e-07  Physic Loss: 8.828399586491287e-06  test imit loss: 9.29783197989309e-07
#
# Epoch 890 : trained for: 61175 -
#  TOT Loss: 1.0151347851206083e-05  Imitation Loss: 9.624968697607983e-07  Boundary Loss: 6.57563475670031e-07  Physic Loss: 8.53128767630551e-06  test imit loss: 9.45254328144074e-07
#
# Epoch 900 : trained for: 61185 -
#  TOT Loss: 1.0229256076854654e-05  Imitation Loss: 8.530810760021268e-07  Boundary Loss: 6.26234111678059e-07  Physic Loss: 8.749941116548143e-06  test imit loss: 9.466426149629115e-07
#
# Epoch 910 : trained for: 61195 -
#  TOT Loss: 1.1421036106185056e-05  Imitation Loss: 1.2546070138341747e-06  Boundary Loss: 6.677554438283551e-07  Physic Loss: 9.498673534835689e-06  test imit loss: 9.335946629107639e-07
#
# Epoch 920 : trained for: 61205 -
#  TOT Loss: 9.572147973813117e-06  Imitation Loss: 9.790587682800833e-07  Boundary Loss: 5.533823923542514e-07  Physic Loss: 8.039706699491944e-06  test imit loss: 9.401609304404701e-07
#
# Epoch 930 : trained for: 61215 -
#  TOT Loss: 9.65522303886246e-06  Imitation Loss: 8.928296324484108e-07  Boundary Loss: 5.907474474042829e-07  Physic Loss: 8.171646186383441e-06  test imit loss: 9.328714440925978e-07
#
# Epoch 940 : trained for: 61225 -
#  TOT Loss: 9.167566531687044e-06  Imitation Loss: 9.704220929052099e-07  Boundary Loss: 5.865840648766607e-07  Physic Loss: 7.610560260218335e-06  test imit loss: 9.378048275721085e-07
#
# Epoch 950 : trained for: 61235 -
#  TOT Loss: 9.878333912638482e-06  Imitation Loss: 9.14241809368832e-07  Boundary Loss: 7.562520067949663e-07  Physic Loss: 8.207840437535197e-06  test imit loss: 9.424074391972681e-07
#
# Epoch 960 : trained for: 61245 -
#  TOT Loss: 9.618569492886309e-06  Imitation Loss: 9.32227749217418e-07  Boundary Loss: 7.26367602510436e-07  Physic Loss: 7.959974027471617e-06  test imit loss: 9.432284286958748e-07
#
# Epoch 970 : trained for: 61255 -
#  TOT Loss: 9.792484888748731e-06  Imitation Loss: 7.753360478091054e-07  Boundary Loss: 6.508944352390245e-07  Physic Loss: 8.366254405700602e-06  test imit loss: 9.46887837471877e-07
#
# Epoch 980 : trained for: 61265 -
#  TOT Loss: 1.1197849744348787e-05  Imitation Loss: 8.459500691060384e-07  Boundary Loss: 6.389998361555627e-07  Physic Loss: 9.712899554870091e-06  test imit loss: 9.36840422127716e-07
#
# Epoch 990 : trained for: 61275 -
#  TOT Loss: 9.315179340774193e-06  Imitation Loss: 7.479127361875726e-07  Boundary Loss: 4.929979127155093e-07  Physic Loss: 8.074268407654017e-06  test imit loss: 9.347660352432285e-07
#
# Epoch 1000 : trained for: 61285 -
#  TOT Loss: 1.0821821888384875e-05  Imitation Loss: 1.1446875305409776e-06  Boundary Loss: 8.809433325041027e-07  Physic Loss: 8.7961907411227e-06  test imit loss: 9.612066378394957e-07
#
# Epoch 1010 : trained for: 61295 -
#  TOT Loss: 9.094927008845843e-06  Imitation Loss: 9.128150963988446e-07  Boundary Loss: 5.030934744354454e-07  Physic Loss: 7.679018381168135e-06  test imit loss: 9.327580983153894e-07
#
# Epoch 1020 : trained for: 61305 -
#  TOT Loss: 1.0888267752307002e-05  Imitation Loss: 9.633001809561392e-07  Boundary Loss: 7.577632459287997e-07  Physic Loss: 9.167204552795738e-06  test imit loss: 9.561036904415232e-07
#
# Epoch 1030 : trained for: 61315 -
#  TOT Loss: 9.50245521380566e-06  Imitation Loss: 8.571417993152863e-07  Boundary Loss: 7.083681339281611e-07  Physic Loss: 7.936945621622726e-06  test imit loss: 9.508239600108936e-07
#
# Epoch 1040 : trained for: 61325 -
#  TOT Loss: 1.0236947673547547e-05  Imitation Loss: 9.0602520685934e-07  Boundary Loss: 8.832344065012876e-07  Physic Loss: 8.447687832813244e-06  test imit loss: 9.280601034333813e-07
#
# Epoch 1050 : trained for: 61335 -
#  TOT Loss: 1.0124993423232809e-05  Imitation Loss: 8.461076390631206e-07  Boundary Loss: 5.857920086782542e-07  Physic Loss: 8.693094059708528e-06  test imit loss: 9.339698294752452e-07
#
# Epoch 1060 : trained for: 61345 -
#  TOT Loss: 9.475469596509356e-06  Imitation Loss: 9.009757491185155e-07  Boundary Loss: 6.047079637028219e-07  Physic Loss: 7.969785656314343e-06  test imit loss: 9.491577088738268e-07
#
# Epoch 1070 : trained for: 61355 -
#  TOT Loss: 1.019994670059532e-05  Imitation Loss: 8.524465897608025e-07  Boundary Loss: 6.269216328291805e-07  Physic Loss: 8.720578989596106e-06  test imit loss: 9.439383461540274e-07
#
# Epoch 1080 : trained for: 61365 -
#  TOT Loss: 1.0206849765381776e-05  Imitation Loss: 7.950241069920594e-07  Boundary Loss: 6.206360581018089e-07  Physic Loss: 8.791189429757651e-06  test imit loss: 9.404682828062505e-07
#
# Epoch 1090 : trained for: 61375 -
#  TOT Loss: 1.0044175724033266e-05  Imitation Loss: 9.112461043514486e-07  Boundary Loss: 6.480133265540644e-07  Physic Loss: 8.484916179440916e-06  test imit loss: 9.319960554421414e-07
#
# Epoch 1100 : trained for: 61385 -
#  TOT Loss: 9.98665109364083e-06  Imitation Loss: 8.941781857174647e-07  Boundary Loss: 6.101727763052622e-07  Physic Loss: 8.482300472678617e-06  test imit loss: 9.251825190403906e-07
#
# Epoch 1110 : trained for: 61395 -
#  TOT Loss: 1.0238304639642593e-05  Imitation Loss: 8.785576142145146e-07  Boundary Loss: 6.008746140651056e-07  Physic Loss: 8.758872354519553e-06  test imit loss: 9.510740710538812e-07
#
# Epoch 1120 : trained for: 61405 -
#  TOT Loss: 9.916014278132934e-06  Imitation Loss: 9.645418685977347e-07  Boundary Loss: 6.479173180196085e-07  Physic Loss: 8.303554750455078e-06  test imit loss: 9.509062692814041e-07
#
# Epoch 1130 : trained for: 61415 -
#  TOT Loss: 1.0371482858317904e-05  Imitation Loss: 8.671249247527157e-07  Boundary Loss: 6.802133043493086e-07  Physic Loss: 8.824144970276393e-06  test imit loss: 9.281496886615059e-07
#
# Epoch 1140 : trained for: 61425 -
#  TOT Loss: 9.725476047606207e-06  Imitation Loss: 1.091044850909384e-06  Boundary Loss: 9.039516726261354e-07  Physic Loss: 7.73047941038385e-06  test imit loss: 9.412482313564396e-07
#
# Epoch 1150 : trained for: 61435 -
#  TOT Loss: 9.954377674148418e-06  Imitation Loss: 9.246393233297567e-07  Boundary Loss: 5.99593363403983e-07  Physic Loss: 8.430145499005448e-06  test imit loss: 9.364720199300791e-07
#
# Epoch 1160 : trained for: 61445 -
#  TOT Loss: 1.0445101906952914e-05  Imitation Loss: 9.152428219749709e-07  Boundary Loss: 5.161671197129181e-07  Physic Loss: 9.013691851578187e-06  test imit loss: 9.401280181009497e-07
#
# Epoch 1170 : trained for: 61455 -
#  TOT Loss: 1.0181506695516873e-05  Imitation Loss: 7.874049288147944e-07  Boundary Loss: 6.567396440004813e-07  Physic Loss: 8.737361895327922e-06  test imit loss: 9.368051223646034e-07
#
# Epoch 1180 : trained for: 61465 -
#  TOT Loss: 9.53624567046063e-06  Imitation Loss: 8.187104754142638e-07  Boundary Loss: 6.637433216383215e-07  Physic Loss: 8.053792043938302e-06  test imit loss: 9.216920489052427e-07
#
# Epoch 1190 : trained for: 61475 -
#  TOT Loss: 9.840428901952691e-06  Imitation Loss: 6.964655767660588e-07  Boundary Loss: 6.703735380142462e-07  Physic Loss: 8.473590241919737e-06  test imit loss: 9.359147270515678e-07
#
# Epoch 1200 : trained for: 61485 -
#  TOT Loss: 1.1068021194660105e-05  Imitation Loss: 8.700822604623681e-07  Boundary Loss: 7.882337627052038e-07  Physic Loss: 9.409704944118857e-06  test imit loss: 9.348368052997102e-07
#
# Epoch 1210 : trained for: 61495 -
#  TOT Loss: 1.0220972399110906e-05  Imitation Loss: 8.109071245598898e-07  Boundary Loss: 6.313223934739653e-07  Physic Loss: 8.778742994763888e-06  test imit loss: 9.327912948720041e-07
#
# Epoch 1220 : trained for: 61505 -
#  TOT Loss: 1.0521423064346891e-05  Imitation Loss: 8.66923073772341e-07  Boundary Loss: 6.969668788769923e-07  Physic Loss: 8.957533282227814e-06  test imit loss: 9.326770396000938e-07
#
# Epoch 1230 : trained for: 61515 -
#  TOT Loss: 1.0399280654382892e-05  Imitation Loss: 8.584500506003678e-07  Boundary Loss: 7.523316867263929e-07  Physic Loss: 8.788499144429807e-06  test imit loss: 9.219722301168076e-07
#
# Epoch 1240 : trained for: 61525 -
#  TOT Loss: 9.664955541666131e-06  Imitation Loss: 7.946458708829596e-07  Boundary Loss: 6.332026032396243e-07  Physic Loss: 8.237107067543548e-06  test imit loss: 9.582213351677638e-07
#
# Epoch 1250 : trained for: 61535 -
#  TOT Loss: 9.896897608996369e-06  Imitation Loss: 8.499208092871413e-07  Boundary Loss: 7.921144060674123e-07  Physic Loss: 8.254862223111559e-06  test imit loss: 9.28177030345978e-07
#
# Epoch 1260 : trained for: 61545 -
#  TOT Loss: 9.644631973060314e-06  Imitation Loss: 7.764417659927858e-07  Boundary Loss: 5.757656822424906e-07  Physic Loss: 8.29242435429478e-06  test imit loss: 9.26518566757295e-07
#
# Epoch 1270 : trained for: 61555 -
#  TOT Loss: 9.89084492175607e-06  Imitation Loss: 7.869257956372167e-07  Boundary Loss: 6.627375910284172e-07  Physic Loss: 8.44118130771676e-06  test imit loss: 9.328045962320175e-07
#
# Epoch 1280 : trained for: 61565 -
#  TOT Loss: 1.0169035704166163e-05  Imitation Loss: 7.713702530054434e-07  Boundary Loss: 6.810220725128602e-07  Physic Loss: 8.716643606021535e-06  test imit loss: 9.199846999763395e-07
#
# Epoch 1290 : trained for: 61575 -
#  TOT Loss: 1.0871130143641494e-05  Imitation Loss: 9.124889857048402e-07  Boundary Loss: 6.24123572379176e-07  Physic Loss: 9.334517926617991e-06  test imit loss: 9.505433240519778e-07
#
# Epoch 1300 : trained for: 61585 -
#  TOT Loss: 1.0459543773322366e-05  Imitation Loss: 8.094773988887027e-07  Boundary Loss: 6.540357162521104e-07  Physic Loss: 8.996030373964459e-06  test imit loss: 9.288174851462827e-07
#
# Epoch 1310 : trained for: 61595 -
#  TOT Loss: 1.0994212061632425e-05  Imitation Loss: 9.73820988292573e-07  Boundary Loss: 5.262537001726741e-07  Physic Loss: 9.494137884757947e-06  test imit loss: 9.279131063522073e-07
#
# Epoch 1320 : trained for: 61605 -
#  TOT Loss: 9.88267311186064e-06  Imitation Loss: 8.983523684946704e-07  Boundary Loss: 5.828562734677689e-07  Physic Loss: 8.401464583585039e-06  test imit loss: 9.318800948676653e-07
#
# Epoch 1330 : trained for: 61615 -
#  TOT Loss: 1.0601911526464391e-05  Imitation Loss: 8.670702982271905e-07  Boundary Loss: 8.049977964219579e-07  Physic Loss: 8.929843716032337e-06  test imit loss: 9.229727879755956e-07
#
# Epoch 1340 : trained for: 61625 -
#  TOT Loss: 1.077666092896834e-05  Imitation Loss: 7.910504677965946e-07  Boundary Loss: 5.351033109946002e-07  Physic Loss: 9.450506695429794e-06  test imit loss: 9.113800274462847e-07
#
# Epoch 1350 : trained for: 61635 -
#  TOT Loss: 1.0067065886687487e-05  Imitation Loss: 8.099054866761435e-07  Boundary Loss: 5.507426976691931e-07  Physic Loss: 8.706418157089502e-06  test imit loss: 9.296111329604173e-07
#
# Epoch 1360 : trained for: 61645 -
#  TOT Loss: 9.757675798027776e-06  Imitation Loss: 9.083449867830495e-07  Boundary Loss: 6.715592917316826e-07  Physic Loss: 8.177771633199882e-06  test imit loss: 9.288616524827376e-07
#
# Epoch 1370 : trained for: 61655 -
#  TOT Loss: 1.005956255539786e-05  Imitation Loss: 7.684139404773305e-07  Boundary Loss: 5.945746011093433e-07  Physic Loss: 8.696573786437511e-06  test imit loss: 9.322341725237493e-07
#
# Epoch 1380 : trained for: 61665 -
#  TOT Loss: 9.619692718842998e-06  Imitation Loss: 7.725915338596678e-07  Boundary Loss: 6.51713435217971e-07  Physic Loss: 8.195387636078522e-06  test imit loss: 9.201525017488166e-07
#
# Epoch 1390 : trained for: 61675 -
#  TOT Loss: 9.52065056480933e-06  Imitation Loss: 8.734576226743229e-07  Boundary Loss: 6.057695145500475e-07  Physic Loss: 8.041423825488891e-06  test imit loss: 9.402688192494679e-07
#
# Epoch 1400 : trained for: 61685 -
#  TOT Loss: 1.0108890819537919e-05  Imitation Loss: 8.767873964643513e-07  Boundary Loss: 6.135467174317455e-07  Physic Loss: 8.618556421424728e-06  test imit loss: 9.425118037142965e-07
#
# Epoch 1410 : trained for: 61695 -
#  TOT Loss: 9.267087079933845e-06  Imitation Loss: 8.724406370674842e-07  Boundary Loss: 6.743783842466655e-07  Physic Loss: 7.720267603872344e-06  test imit loss: 9.229705142388411e-07
#
# Epoch 1420 : trained for: 61705 -
#  TOT Loss: 9.678186870587524e-06  Imitation Loss: 8.732820901968807e-07  Boundary Loss: 5.642443738906877e-07  Physic Loss: 8.240660463343374e-06  test imit loss: 9.352362440040451e-07
#
# Epoch 1430 : trained for: 61715 -
#  TOT Loss: 9.578656317899004e-06  Imitation Loss: 8.669168209962663e-07  Boundary Loss: 5.698359473171877e-07  Physic Loss: 8.141903890646063e-06  test imit loss: 9.292332379118307e-07
#
# Epoch 1440 : trained for: 61725 -
#  TOT Loss: 9.417371984454803e-06  Imitation Loss: 8.329745924129384e-07  Boundary Loss: 6.202124041010393e-07  Physic Loss: 7.964184987940826e-06  test imit loss: 9.26302959669556e-07
#
# Epoch 1450 : trained for: 61735 -
#  TOT Loss: 9.969425263989251e-06  Imitation Loss: 8.95031575964822e-07  Boundary Loss: 6.368730964823044e-07  Physic Loss: 8.437520591542125e-06  test imit loss: 9.559540785630816e-07
#
# Epoch 1460 : trained for: 61745 -
#  TOT Loss: 1.07689456854132e-05  Imitation Loss: 9.094888469007856e-07  Boundary Loss: 5.924481456531794e-07  Physic Loss: 9.267008863389492e-06  test imit loss: 9.432583851776144e-07
#
# Epoch 1470 : trained for: 61755 -
#  TOT Loss: 9.483288522460498e-06  Imitation Loss: 7.357998015322664e-07  Boundary Loss: 6.115969313214009e-07  Physic Loss: 8.135892130667344e-06  test imit loss: 9.2575288590524e-07
#
# Epoch 1480 : trained for: 61765 -
#  TOT Loss: 9.990624675992876e-06  Imitation Loss: 8.163002007677278e-07  Boundary Loss: 7.024615342743346e-07  Physic Loss: 8.47186311148107e-06  test imit loss: 9.244507737093954e-07
#
# Epoch 1490 : trained for: 61775 -
#  TOT Loss: 1.0548712452873588e-05  Imitation Loss: 1.1230591780986288e-06  Boundary Loss: 6.055856260900327e-07  Physic Loss: 8.820067705528345e-06  test imit loss: 9.278072639062884e-07
#
# Epoch 1500 : trained for: 61785 -
#  TOT Loss: 9.789171599550173e-06  Imitation Loss: 9.1970025550836e-07  Boundary Loss: 5.317236855262308e-07  Physic Loss: 8.337747203768231e-06  test imit loss: 9.275847219214484e-07
#
# Epoch 1510 : trained for: 61795 -
#  TOT Loss: 1.0065288734040223e-05  Imitation Loss: 1.169614165519306e-06  Boundary Loss: 5.730345833399042e-07  Physic Loss: 8.322640496771783e-06  test imit loss: 9.259085800294997e-07
#
# Epoch 1520 : trained for: 61805 -
#  TOT Loss: 1.0014631698140875e-05  Imitation Loss: 1.1900071967829717e-06  Boundary Loss: 6.106845376052661e-07  Physic Loss: 8.213939509005286e-06  test imit loss: 9.389224260303308e-07
#
# Epoch 1530 : trained for: 61815 -
#  TOT Loss: 1.0127639143320266e-05  Imitation Loss: 7.813194997652317e-07  Boundary Loss: 7.115967264326173e-07  Physic Loss: 8.634722689748742e-06  test imit loss: 9.3288281277637e-07
#
# Epoch 1540 : trained for: 61825 -
#  TOT Loss: 9.354099347547162e-06  Imitation Loss: 9.391237654199358e-07  Boundary Loss: 5.758469683314615e-07  Physic Loss: 7.839128556952346e-06  test imit loss: 9.348735829917132e-07
#
# Epoch 1550 : trained for: 61835 -
#  TOT Loss: 9.439856512472034e-06  Imitation Loss: 8.041304226935608e-07  Boundary Loss: 7.099661161191761e-07  Physic Loss: 7.925759746285621e-06  test imit loss: 9.220883043781214e-07
#
# Epoch 1560 : trained for: 61845 -
#  TOT Loss: 9.037275958689861e-06  Imitation Loss: 8.284911814371299e-07  Boundary Loss: 6.162669023979106e-07  Physic Loss: 7.592518159071915e-06  test imit loss: 9.438250003768189e-07
#
# Epoch 1570 : trained for: 61855 -
#  TOT Loss: 9.437478183826897e-06  Imitation Loss: 8.898931582734804e-07  Boundary Loss: 7.62456238589948e-07  Physic Loss: 7.785129128023982e-06  test imit loss: 9.214505212185031e-07
#
# Epoch 1580 : trained for: 61865 -
#  TOT Loss: 9.05395791050978e-06  Imitation Loss: 8.513427474099444e-07  Boundary Loss: 6.690872282888449e-07  Physic Loss: 7.533527877967572e-06  test imit loss: 9.178844493362703e-07
#
# Epoch 1590 : trained for: 61875 -
#  TOT Loss: 1.0894777915382292e-05  Imitation Loss: 9.028951808431884e-07  Boundary Loss: 5.763026251770498e-07  Physic Loss: 9.41558027989231e-06  test imit loss: 9.158468969872047e-07
#
# Epoch 1600 : trained for: 61885 -
#  TOT Loss: 9.584688996255863e-06  Imitation Loss: 8.337083841070125e-07  Boundary Loss: 7.021388910288806e-07  Physic Loss: 8.048841664276551e-06  test imit loss: 9.287719535677752e-07
#
# Epoch 1610 : trained for: 61895 -
#  TOT Loss: 1.0197803931077942e-05  Imitation Loss: 1.2837903113904758e-06  Boundary Loss: 6.172982693897211e-07  Physic Loss: 8.296715350297745e-06  test imit loss: 9.213570137944771e-07
#
# Epoch 1620 : trained for: 61905 -
#  TOT Loss: 9.369638974021655e-06  Imitation Loss: 8.078571340774943e-07  Boundary Loss: 7.569515219074674e-07  Physic Loss: 7.804830602253787e-06  test imit loss: 9.306168067269027e-07
#
# Epoch 1630 : trained for: 61915 -
#  TOT Loss: 9.839941412792541e-06  Imitation Loss: 8.6793505715832e-07  Boundary Loss: 6.954991249585873e-07  Physic Loss: 8.276507287519053e-06  test imit loss: 9.388210173710831e-07
#
# Epoch 1640 : trained for: 61925 -
#  TOT Loss: 9.619398042559624e-06  Imitation Loss: 7.898931357885886e-07  Boundary Loss: 6.40768007542647e-07  Physic Loss: 8.188736501324456e-06  test imit loss: 9.210493203681835e-07
#
# Epoch 1650 : trained for: 61935 -
#  TOT Loss: 1.0407586159999482e-05  Imitation Loss: 7.788153197907377e-07  Boundary Loss: 5.597902941190114e-07  Physic Loss: 9.068980943993665e-06  test imit loss: 9.23493701066036e-07
#
# Epoch 1660 : trained for: 61945 -
#  TOT Loss: 1.1342521247570403e-05  Imitation Loss: 8.870742931321729e-07  Boundary Loss: 7.191157465058495e-07  Physic Loss: 9.736330866871867e-06  test imit loss: 9.303363981416624e-07
#
# Epoch 1670 : trained for: 61955 -
#  TOT Loss: 9.668149687058758e-06  Imitation Loss: 8.85910367287579e-07  Boundary Loss: 5.9123010487383e-07  Physic Loss: 8.191009328584187e-06  test imit loss: 9.256196449314302e-07
#
# Epoch 1680 : trained for: 61965 -
#  TOT Loss: 9.596409654477611e-06  Imitation Loss: 8.287488526548259e-07  Boundary Loss: 7.095704859239049e-07  Physic Loss: 8.05809031589888e-06  test imit loss: 9.15122711830918e-07
#
# Epoch 1690 : trained for: 61975 -
#  TOT Loss: 1.0390677743998822e-05  Imitation Loss: 8.336684800269722e-07  Boundary Loss: 5.711981430067681e-07  Physic Loss: 8.985811291495338e-06  test imit loss: 9.346388196718181e-07
#
# Epoch 1700 : trained for: 61985 -
#  TOT Loss: 1.1058994459745008e-05  Imitation Loss: 8.561748359170451e-07  Boundary Loss: 6.784656534364331e-07  Physic Loss: 9.52435402723495e-06  test imit loss: 9.341902114101686e-07
#
# Epoch 1710 : trained for: 61995 -
#  TOT Loss: 1.0596213542157784e-05  Imitation Loss: 8.410968348471215e-07  Boundary Loss: 6.406673378478445e-07  Physic Loss: 9.1144493126194e-06  test imit loss: 9.203625950249261e-07
#
# Epoch 1720 : trained for: 62005 -
#  TOT Loss: 9.209232302964665e-06  Imitation Loss: 8.722070106159663e-07  Boundary Loss: 6.507443686132319e-07  Physic Loss: 7.686280696361791e-06  test imit loss: 9.220727861247724e-07
#
# Epoch 1730 : trained for: 62015 -
#  TOT Loss: 9.662252523412462e-06  Imitation Loss: 9.084250791602244e-07  Boundary Loss: 5.692707532034547e-07  Physic Loss: 8.184556463675108e-06  test imit loss: 9.184163332065509e-07
#
# Epoch 1740 : trained for: 62025 -
#  TOT Loss: 1.0425431355542969e-05  Imitation Loss: 8.033759399950213e-07  Boundary Loss: 6.139589459053241e-07  Physic Loss: 9.00809664017288e-06  test imit loss: 9.381815289088991e-07
#
# Epoch 1750 : trained for: 62035 -
#  TOT Loss: 1.1455214007582981e-05  Imitation Loss: 8.991113986667187e-07  Boundary Loss: 6.363687816701713e-07  Physic Loss: 9.919734111463185e-06  test imit loss: 9.151168001153565e-07
#
# Epoch 1760 : trained for: 62045 -
#  TOT Loss: 1.0262101568514481e-05  Imitation Loss: 8.582975397075643e-07  Boundary Loss: 6.409168236132246e-07  Physic Loss: 8.76288686413318e-06  test imit loss: 9.22580966289388e-07
#
# Epoch 1770 : trained for: 62055 -
#  TOT Loss: 1.0270177881466225e-05  Imitation Loss: 9.661791864346014e-07  Boundary Loss: 5.839543177899031e-07  Physic Loss: 8.720044206711464e-06  test imit loss: 9.136636549555988e-07
#
# Epoch 1780 : trained for: 62065 -
#  TOT Loss: 9.777385457709897e-06  Imitation Loss: 1.2529216064649518e-06  Boundary Loss: 5.850710067534237e-07  Physic Loss: 7.939393071865197e-06  test imit loss: 9.311958706348378e-07
#
# Epoch 1790 : trained for: 62075 -
#  TOT Loss: 1.0655013284122106e-05  Imitation Loss: 8.160848778970831e-07  Boundary Loss: 6.13623285516951e-07  Physic Loss: 9.225304893334396e-06  test imit loss: 9.206532354255614e-07
#
# Epoch 1800 : trained for: 62085 -
#  TOT Loss: 1.0340671906305943e-05  Imitation Loss: 1.200449787575053e-06  Boundary Loss: 6.5378924318793e-07  Physic Loss: 8.486433216603473e-06  test imit loss: 9.157792533187603e-07
#
# Epoch 1810 : trained for: 62095 -
#  TOT Loss: 1.0291953913110774e-05  Imitation Loss: 7.816340144017886e-07  Boundary Loss: 6.8924776996937e-07  Physic Loss: 8.821071787679102e-06  test imit loss: 9.120789741245972e-07
#
# Epoch 1820 : trained for: 62105 -
#  TOT Loss: 9.413525731361005e-06  Imitation Loss: 9.624621952752932e-07  Boundary Loss: 6.28348686859681e-07  Physic Loss: 7.82271490606945e-06  test imit loss: 9.194020549330162e-07
#
# Epoch 1830 : trained for: 62115 -
#  TOT Loss: 9.858354133029934e-06  Imitation Loss: 7.810209012859559e-07  Boundary Loss: 5.913784093536378e-07  Physic Loss: 8.48595482239034e-06  test imit loss: 9.268090366276738e-07
#
# Epoch 1840 : trained for: 62125 -
#  TOT Loss: 1.0572865903668571e-05  Imitation Loss: 8.027699323065463e-07  Boundary Loss: 7.309756142603874e-07  Physic Loss: 9.039120413945056e-06  test imit loss: 9.113720125242253e-07
#
# Epoch 1850 : trained for: 62135 -
#  TOT Loss: 9.637618859414943e-06  Imitation Loss: 9.57841848503449e-07  Boundary Loss: 5.896395123272669e-07  Physic Loss: 8.090137271210551e-06  test imit loss: 9.60882289291476e-07
#
# Epoch 1860 : trained for: 62145 -
#  TOT Loss: 9.184596819977742e-06  Imitation Loss: 8.38909727463033e-07  Boundary Loss: 7.493001703551272e-07  Physic Loss: 7.596387149533257e-06  test imit loss: 9.201308444062306e-07
#
# Epoch 1870 : trained for: 62155 -
#  TOT Loss: 1.0298314919054974e-05  Imitation Loss: 8.172394245775649e-07  Boundary Loss: 7.601245215482777e-07  Physic Loss: 8.720950972929131e-06  test imit loss: 9.353964856018138e-07
#
# Epoch 1880 : trained for: 62165 -
#  TOT Loss: 1.057405552273849e-05  Imitation Loss: 8.20951981950202e-07  Boundary Loss: 6.429524432860489e-07  Physic Loss: 9.11015104065882e-06  test imit loss: 9.167080747829459e-07
#
# Epoch 1890 : trained for: 62175 -
#  TOT Loss: 1.0659330655471422e-05  Imitation Loss: 8.668623650009977e-07  Boundary Loss: 5.686993631570658e-07  Physic Loss: 9.223768756783102e-06  test imit loss: 9.437937364964455e-07
#
# Epoch 1900 : trained for: 62185 -
#  TOT Loss: 1.0078026207338553e-05  Imitation Loss: 8.136741485031962e-07  Boundary Loss: 5.050061986366927e-07  Physic Loss: 8.759346201259177e-06  test imit loss: 9.125160431722179e-07
#
# Epoch 1910 : trained for: 62195 -
#  TOT Loss: 9.984735697798897e-06  Imitation Loss: 8.622101859145914e-07  Boundary Loss: 6.047677061360446e-07  Physic Loss: 8.517758033121936e-06  test imit loss: 9.372070053359494e-07
#
# Epoch 1920 : trained for: 62205 -
#  TOT Loss: 9.112080988415983e-06  Imitation Loss: 8.288983508464298e-07  Boundary Loss: 5.993077252242074e-07  Physic Loss: 7.683875082875602e-06  test imit loss: 9.430869454263302e-07
#
# Epoch 1930 : trained for: 62215 -
#  TOT Loss: 9.585653060639743e-06  Imitation Loss: 1.0722774277382996e-06  Boundary Loss: 6.047661713637353e-07  Physic Loss: 7.908609404694289e-06  test imit loss: 9.23606023661705e-07
#
# Epoch 1940 : trained for: 62225 -
#  TOT Loss: 9.55679115577368e-06  Imitation Loss: 7.944836397655308e-07  Boundary Loss: 6.426256504710182e-07  Physic Loss: 8.119682206597645e-06  test imit loss: 9.231021067535039e-07
#
# Epoch 1950 : trained for: 62235 -
#  TOT Loss: 9.92364584817551e-06  Imitation Loss: 8.080619977590686e-07  Boundary Loss: 6.701420716126449e-07  Physic Loss: 8.445441380899865e-06  test imit loss: 9.173366493087087e-07
#
# Epoch 1960 : trained for: 62245 -
#  TOT Loss: 9.850105925579555e-06  Imitation Loss: 7.759345521662908e-07  Boundary Loss: 5.970068741589785e-07  Physic Loss: 8.477164556097705e-06  test imit loss: 9.059012882062234e-07
#
# Epoch 1970 : trained for: 62255 -
#  TOT Loss: 9.470743862038944e-06  Imitation Loss: 7.471223852917319e-07  Boundary Loss: 6.234668035176583e-07  Physic Loss: 8.100154445855878e-06  test imit loss: 9.011283736981568e-07
#
# Epoch 1980 : trained for: 62265 -
#  TOT Loss: 9.855537427938543e-06  Imitation Loss: 8.47649914703652e-07  Boundary Loss: 5.848882551617862e-07  Physic Loss: 8.422999599133618e-06  test imit loss: 9.216206535711535e-07
#
# Epoch 1990 : trained for: 62275 -
#  TOT Loss: 1.0535059118410572e-05  Imitation Loss: 1.086476231648703e-06  Boundary Loss: 6.696245122839173e-07  Physic Loss: 8.778958545008209e-06  test imit loss: 9.071416684491851e-07
#
# Epoch 2000 : trained for: 62285 -
#  TOT Loss: 1.0433113857288845e-05  Imitation Loss: 7.460222946065187e-07  Boundary Loss: 7.912126420706045e-07  Physic Loss: 8.895878636394627e-06  test imit loss: 9.241530278814025e-07
#
# Epoch 2010 : trained for: 62295 -
#  TOT Loss: 1.0645949259924237e-05  Imitation Loss: 7.762382097098453e-07  Boundary Loss: 6.210718197507958e-07  Physic Loss: 9.248638889403082e-06  test imit loss: 9.09548703020846e-07
#
# Epoch 2020 : trained for: 62305 -
#  TOT Loss: 1.0424015272292309e-05  Imitation Loss: 8.157670663422323e-07  Boundary Loss: 6.716965117448126e-07  Physic Loss: 8.936552148952615e-06  test imit loss: 9.210895086653181e-07
#
# Epoch 2030 : trained for: 62315 -
#  TOT Loss: 1.0049890079244506e-05  Imitation Loss: 8.615382398602378e-07  Boundary Loss: 6.221901571734634e-07  Physic Loss: 8.566161341150291e-06  test imit loss: 9.199551982419507e-07
#
# Epoch 2040 : trained for: 62325 -
#  TOT Loss: 1.0855106665985659e-05  Imitation Loss: 9.126332543019089e-07  Boundary Loss: 6.497090225821012e-07  Physic Loss: 9.292763934354298e-06  test imit loss: 9.120674349105684e-07
#
# Epoch 2050 : trained for: 62335 -
#  TOT Loss: 9.698633220978081e-06  Imitation Loss: 9.356830332762911e-07  Boundary Loss: 5.842861696692125e-07  Physic Loss: 8.178663847502321e-06  test imit loss: 9.266344704883522e-07
#
# Epoch 2060 : trained for: 62345 -
#  TOT Loss: 9.540006431052461e-06  Imitation Loss: 1.0667998822100344e-06  Boundary Loss: 7.029643143141584e-07  Physic Loss: 7.770242518745363e-06  test imit loss: 9.125679412136378e-07
#
# Epoch 2070 : trained for: 62355 -
#  TOT Loss: 9.156157830148004e-06  Imitation Loss: 7.779349857628404e-07  Boundary Loss: 5.747294835600769e-07  Physic Loss: 7.803493645042181e-06  test imit loss: 9.181089239973517e-07
#
# Epoch 2080 : trained for: 62365 -
#  TOT Loss: 9.585440238879528e-06  Imitation Loss: 8.076370363596652e-07  Boundary Loss: 6.453600462918985e-07  Physic Loss: 8.13244332675822e-06  test imit loss: 9.059574495040579e-07
#
# Epoch 2090 : trained for: 62375 -
#  TOT Loss: 1.0252701031276956e-05  Imitation Loss: 9.481535130362317e-07  Boundary Loss: 6.68786640289909e-07  Physic Loss: 8.635760423203465e-06  test imit loss: 9.0652667950053e-07
#
# Epoch 2100 : trained for: 62385 -
#  TOT Loss: 9.990557373384945e-06  Imitation Loss: 9.505840239398822e-07  Boundary Loss: 7.431003723468166e-07  Physic Loss: 8.296872692881152e-06  test imit loss: 9.186341003442067e-07
#
# Epoch 2110 : trained for: 62395 -
#  TOT Loss: 1.0191682122240309e-05  Imitation Loss: 9.992908189815353e-07  Boundary Loss: 4.803927140528685e-07  Physic Loss: 8.71199881657958e-06  test imit loss: 9.062489425559761e-07
#
# Epoch 2120 : trained for: 62405 -
#  TOT Loss: 9.301454156229738e-06  Imitation Loss: 8.966691211753641e-07  Boundary Loss: 5.748505600422504e-07  Physic Loss: 7.829934475012124e-06  test imit loss: 9.106082643484115e-07
#
# Epoch 2130 : trained for: 62415 -
#  TOT Loss: 9.758897249412257e-06  Imitation Loss: 7.841984484002751e-07  Boundary Loss: 6.441784421440389e-07  Physic Loss: 8.330520358867943e-06  test imit loss: 9.266404390473326e-07
#
# Epoch 2140 : trained for: 62425 -
#  TOT Loss: 9.80442655418301e-06  Imitation Loss: 8.041851060625049e-07  Boundary Loss: 6.401379550879938e-07  Physic Loss: 8.360103493032511e-06  test imit loss: 9.283707527174556e-07
#
# Epoch 2150 : trained for: 62435 -
#  TOT Loss: 9.895811672322452e-06  Imitation Loss: 8.067577823567262e-07  Boundary Loss: 7.92044716035889e-07  Physic Loss: 8.297009117086418e-06  test imit loss: 9.277692356590705e-07
#
# Epoch 2160 : trained for: 62445 -
#  TOT Loss: 1.0490261956874747e-05  Imitation Loss: 8.218479479182861e-07  Boundary Loss: 5.800769713459886e-07  Physic Loss: 9.088336810236797e-06  test imit loss: 9.332183026344865e-07
#
# Epoch 2170 : trained for: 62455 -
# ...
#
# Epoch 12160 : trained for: 72445 -
#  TOT Loss: 7.452478257619077e-06  Imitation Loss: 7.164079534049961e-07  Boundary Loss: 4.976810146217758e-07  Physic Loss: 6.2383892327488866e-06  test imit loss: 7.252903628796048e-07
#
# Epoch 12170 : trained for: 72455 -
#  TOT Loss: 7.659437869733665e-06  Imitation Loss: 6.331591180241958e-07  Boundary Loss: 4.864924108005653e-07  Physic Loss: 6.539786227222066e-06  test imit loss: 7.475938446077635e-07
#
# Epoch 12180 : trained for: 72465 -
#  TOT Loss: 8.758535841479897e-06  Imitation Loss: 6.79264076097752e-07  Boundary Loss: 5.032754870626377e-07  Physic Loss: 7.575996278319508e-06  test imit loss: 7.301854907382221e-07
#
# Epoch 12190 : trained for: 72475 -
#  TOT Loss: 7.952366104291286e-06  Imitation Loss: 6.854564276181918e-07  Boundary Loss: 4.8034024757726e-07  Physic Loss: 6.7865694290958345e-06  test imit loss: 7.434844633280591e-07
#
# Epoch 12200 : trained for: 72485 -
#  TOT Loss: 8.854354746290483e-06  Imitation Loss: 1.0504069223316037e-06  Boundary Loss: 5.061048682364344e-07  Physic Loss: 7.297842785192188e-06  test imit loss: 7.263166139637178e-07
#
# Epoch 12210 : trained for: 72495 -
#  TOT Loss: 8.61056014400674e-06  Imitation Loss: 9.031458603203646e-07  Boundary Loss: 4.881773634224373e-07  Physic Loss: 7.219236977107357e-06  test imit loss: 7.341906211877358e-07
#
# Epoch 12220 : trained for: 72505 -
#  TOT Loss: 7.821096914994996e-06  Imitation Loss: 7.290287271644047e-07  Boundary Loss: 5.120815558257164e-07  Physic Loss: 6.5799868025351316e-06  test imit loss: 7.211123147499165e-07
#
# Epoch 12230 : trained for: 72515 -
#  TOT Loss: 8.438975783064961e-06  Imitation Loss: 7.365501346612291e-07  Boundary Loss: 4.579661379011668e-07  Physic Loss: 7.244459538924275e-06  test imit loss: 7.461192126356764e-07
#
# Epoch 12240 : trained for: 72525 -
#  TOT Loss: 8.192399036488496e-06  Imitation Loss: 5.893256798117363e-07  Boundary Loss: 5.3308843916966e-07  Physic Loss: 7.069985258567613e-06  test imit loss: 7.221757414299645e-07
#
# Epoch 12250 : trained for: 72535 -
#  TOT Loss: 8.078322025539819e-06  Imitation Loss: 6.259511451389699e-07  Boundary Loss: 4.465390475161257e-07  Physic Loss: 7.005831776041305e-06  test imit loss: 7.250470162034617e-07
#
# Epoch 12260 : trained for: 72545 -
#  TOT Loss: 8.62823253555689e-06  Imitation Loss: 7.378970963145548e-07  Boundary Loss: 5.204989292906248e-07  Physic Loss: 7.36983702154248e-06  test imit loss: 7.425986154885322e-07
#
# Epoch 12270 : trained for: 72555 -
#  TOT Loss: 8.089754373941105e-06  Imitation Loss: 7.420885026476753e-07  Boundary Loss: 5.611182700704376e-07  Physic Loss: 6.786547601222992e-06  test imit loss: 7.325208457586996e-07
#
# Epoch 12280 : trained for: 72565 -
#  TOT Loss: 8.26790801511379e-06  Imitation Loss: 9.30238513774384e-07  Boundary Loss: 4.5204524212749675e-07  Physic Loss: 6.885624316055328e-06  test imit loss: 7.192664384092495e-07
#
# Epoch 12290 : trained for: 72575 -
#  TOT Loss: 8.628810064692516e-06  Imitation Loss: 8.210348028114822e-07  Boundary Loss: 4.757457645609975e-07  Physic Loss: 7.33202932678978e-06  test imit loss: 7.453253942912852e-07
#
# Epoch 12300 : trained for: 72585 -
#  TOT Loss: 8.323416295752395e-06  Imitation Loss: 7.415073923766613e-07  Boundary Loss: 5.008641892345622e-07  Physic Loss: 7.0810447141411714e-06  test imit loss: 7.243910999932268e-07
#
# Epoch 12310 : trained for: 72595 -
#  TOT Loss: 7.935250323498622e-06  Imitation Loss: 7.591093549308425e-07  Boundary Loss: 4.162748155067675e-07  Physic Loss: 6.759866664651781e-06  test imit loss: 7.451039323314035e-07
#
# Epoch 12320 : trained for: 72605 -
#  TOT Loss: 8.125588465190958e-06  Imitation Loss: 6.636525995418197e-07  Boundary Loss: 5.109644121148449e-07  Physic Loss: 6.9509715103777125e-06  test imit loss: 7.326408422159147e-07
#
# Epoch 12330 : trained for: 72615 -
#  TOT Loss: 8.058181265369058e-06  Imitation Loss: 7.170766025410558e-07  Boundary Loss: 5.377493152991519e-07  Physic Loss: 6.803355063311756e-06  test imit loss: 7.226801699289354e-07
#
# Epoch 12340 : trained for: 72625 -
#  TOT Loss: 7.650183761143126e-06  Imitation Loss: 7.476429573216592e-07  Boundary Loss: 4.204704282528837e-07  Physic Loss: 6.482070602942258e-06  test imit loss: 7.29542762201163e-07
#
# Epoch 12350 : trained for: 72635 -
#  TOT Loss: 8.584225724916905e-06  Imitation Loss: 6.502258997898025e-07  Boundary Loss: 6.182943934618379e-07  Physic Loss: 7.315705715882359e-06  test imit loss: 7.229782568174414e-07
#
# Epoch 12360 : trained for: 72645 -
#  TOT Loss: 8.7070839072112e-06  Imitation Loss: 8.702275522409764e-07  Boundary Loss: 4.352471023594262e-07  Physic Loss: 7.401609764201567e-06  test imit loss: 7.38837513836188e-07
#
# Epoch 12370 : trained for: 72655 -
#  TOT Loss: 8.584365787100978e-06  Imitation Loss: 5.905859552512993e-07  Boundary Loss: 6.620764452236472e-07  Physic Loss: 7.331703727686545e-06  test imit loss: 7.382691933344177e-07
#
# Epoch 12380 : trained for: 72665 -
#  TOT Loss: 8.03097373136552e-06  Imitation Loss: 7.291247356988606e-07  Boundary Loss: 5.908627258577326e-07  Physic Loss: 6.710986326652346e-06  test imit loss: 7.30141437088605e-07
#
# Epoch 12390 : trained for: 72675 -
#  TOT Loss: 7.887172614573501e-06  Imitation Loss: 6.897965363350522e-07  Boundary Loss: 4.745411104067898e-07  Physic Loss: 6.722834768879693e-06  test imit loss: 7.276796054611623e-07
#
# Epoch 12400 : trained for: 72685 -
#  TOT Loss: 8.204086043406278e-06  Imitation Loss: 6.013317488395842e-07  Boundary Loss: 4.4575944002644974e-07  Physic Loss: 7.156995252444176e-06  test imit loss: 7.205543965937977e-07
#
# Epoch 12410 : trained for: 72695 -
#  TOT Loss: 8.30756198411109e-06  Imitation Loss: 7.38931021260214e-07  Boundary Loss: 5.595382503997826e-07  Physic Loss: 7.0090927692945115e-06  test imit loss: 7.226622074085753e-07
#
# Epoch 12420 : trained for: 72705 -
#  TOT Loss: 8.362809239770286e-06  Imitation Loss: 6.899634854562464e-07  Boundary Loss: 4.5891042077528255e-07  Physic Loss: 7.213935077743372e-06  test imit loss: 7.300027391465846e-07
#
# Epoch 12430 : trained for: 72715 -
#  TOT Loss: 8.483581950713415e-06  Imitation Loss: 7.070023571031925e-07  Boundary Loss: 7.243867798933934e-07  Physic Loss: 7.052192813716829e-06  test imit loss: 7.32145792881056e-07
#
# Epoch 12440 : trained for: 72725 -
#  TOT Loss: 8.330986929649953e-06  Imitation Loss: 7.232654297695262e-07  Boundary Loss: 4.3875394339920604e-07  Physic Loss: 7.168967385950964e-06  test imit loss: 7.459527751052519e-07
#
# Epoch 12450 : trained for: 72735 -
#  TOT Loss: 8.199371222872287e-06  Imitation Loss: 8.398492923333833e-07  Boundary Loss: 4.839789653487969e-07  Physic Loss: 6.8755434767808765e-06  test imit loss: 7.415505933749955e-07
#
# Epoch 12460 : trained for: 72745 -
#  TOT Loss: 8.837063433020376e-06  Imitation Loss: 7.24232961601956e-07  Boundary Loss: 5.476801447912294e-07  Physic Loss: 7.565150554000866e-06  test imit loss: 7.299786375369877e-07
#
# Epoch 12470 : trained for: 72755 -
#  TOT Loss: 8.807500307739247e-06  Imitation Loss: 6.406872330444457e-07  Boundary Loss: 4.775284878633101e-07  Physic Loss: 7.689284757361747e-06  test imit loss: 7.320049917325377e-07
#
# Epoch 12480 : trained for: 72765 -
#  TOT Loss: 8.351094038516749e-06  Imitation Loss: 6.654835260633263e-07  Boundary Loss: 4.571987801682553e-07  Physic Loss: 7.2284119596588425e-06  test imit loss: 7.229713219203404e-07
#
# Epoch 12490 : trained for: 72775 -
#  TOT Loss: 8.141380931192543e-06  Imitation Loss: 6.64322612919932e-07  Boundary Loss: 5.042265911470167e-07  Physic Loss: 6.972831670282176e-06  test imit loss: 7.250033036143577e-07
#
# Epoch 12500 : trained for: 72785 -
#  TOT Loss: 8.589553544879891e-06  Imitation Loss: 6.593006105504173e-07  Boundary Loss: 4.3694427631635335e-07  Physic Loss: 7.49330865801312e-06  test imit loss: 7.18814590072725e-07
#
# Epoch 12510 : trained for: 72795 -
#  TOT Loss: 8.032349796849303e-06  Imitation Loss: 6.812934429945017e-07  Boundary Loss: 4.46946700094486e-07  Physic Loss: 6.904109795868862e-06  test imit loss: 7.172222353801772e-07
#
# Epoch 12520 : trained for: 72805 -
#  TOT Loss: 8.26674386189552e-06  Imitation Loss: 6.725026082676777e-07  Boundary Loss: 4.7166707872747793e-07  Physic Loss: 7.122574515960878e-06  test imit loss: 7.336454359574418e-07
#
# Epoch 12530 : trained for: 72815 -
#  TOT Loss: 9.057578608917538e-06  Imitation Loss: 7.70031306274177e-07  Boundary Loss: 5.722870355384657e-07  Physic Loss: 7.715259926044382e-06  test imit loss: 7.465961857633374e-07
#
# Epoch 12540 : trained for: 72825 -
#  TOT Loss: 8.572963452024851e-06  Imitation Loss: 7.086506457198993e-07  Boundary Loss: 4.2440100855856144e-07  Physic Loss: 7.439911769324681e-06  test imit loss: 7.183806474131416e-07
#
# Epoch 12550 : trained for: 72835 -
#  TOT Loss: 9.169778422801755e-06  Imitation Loss: 9.391679327563907e-07  Boundary Loss: 5.904618092245073e-07  Physic Loss: 7.640148396603763e-06  test imit loss: 7.367244165834563e-07
#
# Epoch 12560 : trained for: 72845 -
#  TOT Loss: 8.497744602209423e-06  Imitation Loss: 6.660101234956528e-07  Boundary Loss: 4.0721982941249735e-07  Physic Loss: 7.424514478771016e-06  test imit loss: 7.242328479151183e-07
#
# Epoch 12570 : trained for: 72855 -
#  TOT Loss: 8.468094165436924e-06  Imitation Loss: 5.961319402558729e-07  Boundary Loss: 4.789660579263e-07  Physic Loss: 7.392996394628426e-06  test imit loss: 7.283318836925901e-07
#
# Epoch 12580 : trained for: 72865 -
#  TOT Loss: 7.598257070640102e-06  Imitation Loss: 6.589713166249567e-07  Boundary Loss: 4.109005544705724e-07  Physic Loss: 6.528385256387992e-06  test imit loss: 7.34903153443156e-07
#
# Epoch 12590 : trained for: 72875 -
#  TOT Loss: 8.758886906434782e-06  Imitation Loss: 6.810102490817371e-07  Boundary Loss: 5.012904011891806e-07  Physic Loss: 7.5765865403809585e-06  test imit loss: 7.285994456651679e-07
#
# Epoch 12600 : trained for: 72885 -
#  TOT Loss: 8.297520253108814e-06  Imitation Loss: 6.854024832136929e-07  Boundary Loss: 4.665909045797889e-07  Physic Loss: 7.145526524254819e-06  test imit loss: 7.22085701454489e-07
#
# Epoch 12610 : trained for: 72895 -
#  TOT Loss: 7.731512596365064e-06  Imitation Loss: 6.398081495717634e-07  Boundary Loss: 4.865911478191265e-07  Physic Loss: 6.605113412661012e-06  test imit loss: 7.197733111752314e-07
#
# Epoch 12620 : trained for: 72905 -
#  TOT Loss: 8.230920684582088e-06  Imitation Loss: 7.592722113258787e-07  Boundary Loss: 4.666039785661269e-07  Physic Loss: 7.00504460837692e-06  test imit loss: 7.36933657208283e-07
#
# Epoch 12630 : trained for: 72915 -
#  TOT Loss: 7.98829751147423e-06  Imitation Loss: 6.667730190201837e-07  Boundary Loss: 4.847821628573001e-07  Physic Loss: 6.836742159066489e-06  test imit loss: 7.22858374047064e-07
#
# Epoch 12640 : trained for: 72925 -
#  TOT Loss: 8.200093361665495e-06  Imitation Loss: 6.527611731144134e-07  Boundary Loss: 4.911928499495843e-07  Physic Loss: 7.0561395659751724e-06  test imit loss: 7.375625727945589e-07
#
# Epoch 12650 : trained for: 72935 -
#  TOT Loss: 8.599432476330549e-06  Imitation Loss: 7.063569569254469e-07  Boundary Loss: 6.172114694891206e-07  Physic Loss: 7.275864390976494e-06  test imit loss: 7.190479323071486e-07
#
# Epoch 12660 : trained for: 72945 -
#  TOT Loss: 8.76651392900385e-06  Imitation Loss: 8.110380917969451e-07  Boundary Loss: 5.522020956050255e-07  Physic Loss: 7.403274139505811e-06  test imit loss: 7.305644658117671e-07
#
# Epoch 12670 : trained for: 72955 -
#  TOT Loss: 7.760929292999208e-06  Imitation Loss: 9.103894740292162e-07  Boundary Loss: 4.889902811555658e-07  Physic Loss: 6.361549367284169e-06  test imit loss: 7.312267484849144e-07
#
# Epoch 12680 : trained for: 72965 -
#  TOT Loss: 8.06701063993387e-06  Imitation Loss: 6.867467163829133e-07  Boundary Loss: 4.39868017565459e-07  Physic Loss: 6.940395451238146e-06  test imit loss: 7.341828336393519e-07
#
# Epoch 12690 : trained for: 72975 -
#  TOT Loss: 7.890149390732404e-06  Imitation Loss: 7.467917271242186e-07  Boundary Loss: 4.679757807934948e-07  Physic Loss: 6.6753818828146905e-06  test imit loss: 7.662407597308629e-07
#
# Epoch 12700 : trained for: 72985 -
#  TOT Loss: 7.977625500643626e-06  Imitation Loss: 7.852652856854547e-07  Boundary Loss: 4.212462840769149e-07  Physic Loss: 6.771113476133905e-06  test imit loss: 7.210146009128948e-07
#
# Epoch 12710 : trained for: 72995 -
#  TOT Loss: 7.97420580056496e-06  Imitation Loss: 6.626950153076905e-07  Boundary Loss: 4.5005796778241347e-07  Physic Loss: 6.8614526753663085e-06  test imit loss: 7.2420482410962e-07
#
# Epoch 12720 : trained for: 73005 -
#  TOT Loss: 7.978746907610912e-06  Imitation Loss: 6.858074925730762e-07  Boundary Loss: 4.680191523220856e-07  Physic Loss: 6.8249200921854936e-06  test imit loss: 7.309097327379277e-07
#
# Epoch 12730 : trained for: 73015 -
#  TOT Loss: 7.834485586499795e-06  Imitation Loss: 5.990384579490637e-07  Boundary Loss: 4.4748844629793894e-07  Physic Loss: 6.787958682252793e-06  test imit loss: 7.225070248750853e-07
#
# Epoch 12740 : trained for: 73025 -
#  TOT Loss: 8.340339263668284e-06  Imitation Loss: 5.595214247477998e-07  Boundary Loss: 5.47833849395829e-07  Physic Loss: 7.232983534777304e-06  test imit loss: 7.248752353916643e-07
#
# Epoch 12750 : trained for: 73035 -
#  TOT Loss: 8.00473935669288e-06  Imitation Loss: 9.240476970262534e-07  Boundary Loss: 5.036840207139903e-07  Physic Loss: 6.5770072978921235e-06  test imit loss: 7.393778673758788e-07
#
# Epoch 12760 : trained for: 73045 -
#  TOT Loss: 8.359953426406719e-06  Imitation Loss: 7.297543902495818e-07  Boundary Loss: 5.517769068319467e-07  Physic Loss: 7.07842264091596e-06  test imit loss: 7.406055146930157e-07
#
# Epoch 12770 : trained for: 73055 -
#  TOT Loss: 8.227914804592729e-06  Imitation Loss: 6.251233344300999e-07  Boundary Loss: 6.175976068334421e-07  Physic Loss: 6.985193522268673e-06  test imit loss: 7.273057462953147e-07
#
# Epoch 12780 : trained for: 73065 -
#  TOT Loss: 7.432719939970411e-06  Imitation Loss: 7.876126915107307e-07  Boundary Loss: 4.4814123612013645e-07  Physic Loss: 6.196965841809288e-06  test imit loss: 7.227798164421984e-07
#
# Epoch 12790 : trained for: 73075 -
#  TOT Loss: 7.872153219068423e-06  Imitation Loss: 6.428863912333327e-07  Boundary Loss: 4.87432203044591e-07  Physic Loss: 6.74183456794708e-06  test imit loss: 7.357456297540921e-07
#
# Epoch 12800 : trained for: 73085 -
#  TOT Loss: 7.988397555891424e-06  Imitation Loss: 6.828662435509614e-07  Boundary Loss: 5.532380100703449e-07  Physic Loss: 6.752293757017469e-06  test imit loss: 7.142006097637932e-07
#
# Epoch 12810 : trained for: 73095 -
#  TOT Loss: 8.22010770207271e-06  Imitation Loss: 9.259298394681537e-07  Boundary Loss: 4.809971869690344e-07  Physic Loss: 6.8131807893223595e-06  test imit loss: 7.117550353541446e-07
#
# Epoch 12820 : trained for: 73105 -
#  TOT Loss: 8.144726962200366e-06  Imitation Loss: 6.002547365824284e-07  Boundary Loss: 5.933027864557516e-07  Physic Loss: 6.951169780222699e-06  test imit loss: 7.205518954833678e-07
#
# Epoch 12830 : trained for: 73115 -
#  TOT Loss: 7.640491276106331e-06  Imitation Loss: 6.352775585583004e-07  Boundary Loss: 5.713598625334271e-07  Physic Loss: 6.433854196075117e-06  test imit loss: 7.254096772157936e-07
#
# Epoch 12840 : trained for: 73125 -
#  TOT Loss: 7.977369023137726e-06  Imitation Loss: 6.247648798307637e-07  Boundary Loss: 5.456761300592916e-07  Physic Loss: 6.80692755850032e-06  test imit loss: 7.341874947996985e-07
#
# Epoch 12850 : trained for: 73135 -
#  TOT Loss: 7.848840141377877e-06  Imitation Loss: 7.569992135358916e-07  Boundary Loss: 4.663941126636928e-07  Physic Loss: 6.62544698570855e-06  test imit loss: 7.239451633722638e-07
#
# Epoch 12860 : trained for: 73145 -
#  TOT Loss: 7.83041468821466e-06  Imitation Loss: 6.699413575006474e-07  Boundary Loss: 6.192135515448172e-07  Physic Loss: 6.541260063386289e-06  test imit loss: 7.223987381621555e-07
#
# Epoch 12870 : trained for: 73155 -
#  TOT Loss: 8.70651456352789e-06  Imitation Loss: 6.231429097169894e-07  Boundary Loss: 4.4853851477455464e-07  Physic Loss: 7.634833309566602e-06  test imit loss: 7.460175197593344e-07

# %%
torch.save(learner.model.state_dict(), 'model_epochs_60_218_extra_small_input.pth')

# %%
# Extracting values for each key
imit_loss = [entry['imit_loss'] for entry in log_loss_train]
boundary_loss = [entry['boundary_loss'] for entry in log_loss_train]
physic_loss = [entry['physic_loss'] for entry in log_loss_train]
total_loss = [entry['total_loss'] for entry in log_loss_train]

# %%
skipp_train = 25000
skipp_test = 2000
plt.plot(imit_loss[skipp_train::10], label='train')
plt.plot(np.array(log_loss_test)[skipp_test:], label='test')
plt.legend()

# %%
"n epochs" , len(total_loss)
# Out:
# ('n epochs', 60218)

# %%
skipp = 30000
step = 50

plt.plot(imit_loss[skipp::step], label = 'Imitation loss')
plt.plot(boundary_loss[skipp::step], label = 'Boundary loss')
plt.plot(physic_loss[skipp::step], label = 'Physics loss')
plt.plot(total_loss[skipp::step], label = 'Total loss')
plt.grid()
plt.legend()

# %%
state_init = torch.Tensor([1, 0.2, 3]).to('cuda')
vel = torch.Tensor([0.0, -0.0]).to('cuda')
t = torch.Tensor([0.08]).to('cuda')

states = [state_init]

for _ in range(100):

    with torch.no_grad():
        input_pair = torch.cat([states[-1], vel, t]).to('cuda')
        state = learner.model(input_pair)
        states.append(state)

state = states[0]
states_model = [state]
for _ in range(100):

    x_dot = torch.cos(states_model[-1][2])*vel[0]
    y_dot = torch.sin(states_model[-1][2])*vel[0]
    theta_dot = vel[1]

    states_model.append(
        states_model[-1] + torch.Tensor([x_dot, y_dot, theta_dot]).to('cuda') * t
    )

state = torch.vstack(states).cpu().numpy()
state_model = torch.vstack(states_model).cpu().numpy()
plt.plot(state[:, 0], state[:, 1], label='pinn')
plt.plot(state_model[:, 0], state_model[:, 1], label='euler')
plt.axis('equal')
plt.legend()

# %%
max_range, min_range
# Out:
# (tensor([5.6094, 5.6092, 5.6091, 0.9999, 1.0000, 0.0900]),
#  tensor([-5.1768, -5.1780, -5.1792, -0.9998, -1.0000,  0.0000]))
